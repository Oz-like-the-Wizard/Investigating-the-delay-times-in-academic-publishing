# %%
import pandas as pd
import pickle 

from scihub_upgraded import SciHub
from crossref.restful import Works, Etiquette

import warnings
warnings.filterwarnings("ignore")

# %%
# %store -r retr_complete_one
# %store -r date_df
# %store -r second_run_df

# %%
with open("second_run_df", "rb") as fp:
    second_run_df = pickle.load(fp)

# %%
my_etiquette = Etiquette('Analysing Publishing Delay in Academic Journals', 'v2.0', 'https://github.com/Spidey0023/THEsis-Codes', 'oguzkokes@gmail.com')
ogi_works = Works(etiquette=my_etiquette)

# %%
second_run_df
# Out:
#                         Issn  Year  Total_Docs  Sample_Count CrossRef_retr  \
# 0                 [00011541]  2010         294             1          True
# 1                 [00011541]  2011         315             1          True
# 2                 [00011541]  2012         347             1          True
# 21                [00013765]  2020         363             1          True
# 22                [00014273]  2010          70             1          True
# ...                      ...   ...         ...           ...           ...
# 74404             [87563282]  2016         274             1          True
# 74409  [8756758X,  14602695]  2010          76             1          True
# 74410  [8756758X,  14602695]  2011          91             1          True
# 74411  [8756758X,  14602695]  2012         102             1          True
# 74420  [8756971X,  19436270]  2010          69             1          True
#
#                                     DOI  \
# ...

# %%
def CrossRef_meta(ISSN, year, sample):
    # This function takes .map() or apply() loop through a dataframe as input and gives out a DICT that is converted to a DATAFRAME inside the function as output 
    cr_keys = ["DOI", "title", "author", "subject", "references-count", "is-referenced-by-count"]
    jrnl_df = pd.DataFrame()
    works = Works(etiquette=my_etiquette)
    # here add .count() checkpoints for article retrival count
    w1 = works.filter(issn=ISSN,from_issued_date=year, until_issued_date=year, type="journal-article").sample(sample).select("DOI", "title", "author", "subject", "references-count", "is-referenced-by-count")
    for work in w1:
        for key in cr_keys:
            if key == "author":
                try:
                    jrnl_df.loc[work["DOI"], "f_name"] = work["author"][0]["given"]
                    jrnl_df.loc[work["DOI"], "l_name"] = work["author"][0]["family"]

                except:
                    pass
            else:
                try:
                    jrnl_df.loc[work["DOI"], key] = work[key]
                except:
                    jrnl_df.loc[work["DOI"], key] = np.nan    
    return jrnl_df
