# %%
import pandas as pd
import pickle 
import numpy as np

from scihub_upgraded import SciHub
from crossref.restful import Works, Etiquette

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Part 1:
# Get CR metadata & Second_CR_retr results for second_run

# %%
# %store -r retr_complete_one
# %store -r date_df
# %store -r second_run_df

# %%
with open("second_run_df", "rb") as fp:
    second_run_df = pickle.load(fp)

# %%
my_etiquette = Etiquette('Analysing Publishing Delay in Academic Journals', 'v2.0', 'https://github.com/Spidey0023/THEsis-Codes', 'oguzkokes@gmail.com')
ogi_works = Works(etiquette=my_etiquette)

# %%
# The full loop code:

issn_rry = second_run_df.Issn.values
year_rry = second_run_df.Year.values

#second_run_df.reset_index(drop=True, inplace=True)

full_meta_list = []
useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'reference', 'container-title', 'issued', 'ISSN', 'subject']

for i in range(len(second_run_df)):
    issn = issn_rry[i]
    year = year_rry[i]
    loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(2).select(useful_cols)] 

    if len(loop_meta) == 0:
        second_run_df.loc[second_run_df.index[i],"Second_CR_retr"] = False
    else:
        second_run_df.loc[second_run_df.index[i],"Second_CR_retr"] = True

    full_meta_list.extend(loop_meta)

# %% [markdown]
# The code above will be modified for SumCetCet conditions.

# %%
cet_second_run = second_run_df[:15000]
sum_second_run = second_run_df[15000:30000]
ogi_second_run = second_run_df[30000:]

# %%
# The Ogi loop code:

issn_rry = ogi_second_run.Issn.values
year_rry = ogi_second_run.Year.values

ogi_meta_list = []
useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'reference', 'container-title', 'issued', 'ISSN', 'subject']

for i in range(len(ogi_second_run)):
    issn = issn_rry[i]
    year = year_rry[i]
    loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(2).select(useful_cols)] 

    if len(loop_meta) == 0:
        ogi_second_run.loc[ogi_second_run.index[i],"Second_CR_retr"] = False
    else:
        ogi_second_run.loc[ogi_second_run.index[i],"Second_CR_retr"] = True

    ogi_meta_list.extend(loop_meta)

# %% [markdown]
# ## PART 2:
# CR meta retr SumCetCet runs are complete, the analysis can continue below for SciHub get_dates() for retrieved articles.

# %%
# %store -r ogi_meta_list
# %store -r ogi_second_run

with open("cet_meta_list", "rb") as fp:
    cet_meta_list = pickle.load(fp)

with open("cet_second_run", "rb") as fp:
    cet_second_run = pickle.load(fp)

with open("sum_meta_list", "rb") as fp:
    sum_meta_list = pickle.load(fp)

with open("sum_second_run", "rb") as fp:
    sum_second_run = pickle.load(fp)

# %%
# to get "Second_CR_retr" column:
second_run_df = pd.concat([cet_second_run,sum_second_run, ogi_second_run], verify_integrity=True)

# %%
full_meta_list = cet_meta_list + sum_meta_list + ogi_meta_list

second_run_meta = pd.DataFrame(full_meta_list)

# %% [markdown]
# * Create a YEAR column based on pub-print
# * .groupby(ISSN & YEAR)["DOI"].apply(list)
# * Make a function where if first has date skip second
# * Else try second one
# * If can get a date from one save DOI & date info

# %%
second_run_meta["Year"] = second_run_meta.issued.map(lambda x: x["date-parts"][0][0])
second_run_meta["ISSN"] = second_run_meta.ISSN.map(tuple)

second_run_doi_group = second_run_meta.groupby(["ISSN","Year"])["DOI"].apply(list)

second_run_doi_rry = second_run_doi_group.values

# %%
second_run_doi_group.map(len).value_counts()
# Out:
# 2    32204
# 1     1687
# 4        3
# 3        1
# Name: DOI, dtype: int64

# %% [markdown]
# Here we have 3 important variables in this notebook:
#
# 1- second_run_df -> this is the now updated version as it also has "Second_CR_retr" column -> can be SAVEd
#
# 2- second_run_meta -> this df contains NEW article metadata retrieved for second_run tests
#
# 3- second_run_doi_rry -> this np.array contains .groupby(Issn,year)["DOI"] to be used in a SciHub get_dates() loop
#
# As a result of the sh.get_dates() run, second_run_dates_dict will be created -> this will contain DOI Scihub_results, which then can be used to match with second_run_meta & second_run_df.
#
# This will finalize the available journals for the FINAL_100K run!

# %%
with open("second_run_doi_rry","wb") as fp:
    pickle.dump(second_run_doi_rry, fp)

# %%
# Full Run Version:

sh = SciHub()
second_run_dates_dict = {}

for rry in second_run_doi_rry:
    for ind, doi in enumerate(rry):
        date = sh.get_dates(doi)
        second_run_dates_dict[doi] = date
        if type(date) == list:
            if len(date) == 3:
                for i in range (ind+1,len(rry)):
                    second_run_dates_dict[rry[i]] = "skipped"
                break

# %%
cet_doi_rry = second_run_doi_rry[:11000]
sum_doi_rry = second_run_doi_rry[11000:22000]
ogi_doi_rry = second_run_doi_rry[22000:]

# %%
# SumCetCet - Ogi Version

sh = SciHub()
ogi_dates_dict = {}

for rry in ogi_doi_rry:
    for ind, doi in enumerate(rry):
        date = sh.get_dates(doi)
        ogi_dates_dict[doi] = date
        if type(date) == list:
            if len(date) == 3:
                for i in range (ind+1,len(rry)):
                    ogi_dates_dict[rry[i]] = "skipped"
                break
# Out:
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/2667/229ae24be5416d26ffc766a9f401179f/rawal2014.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14442213.2018.1553205.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14601176.2014.980066.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1093/brain%252Fawt002.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/4061/8aeaa6e3476874b711726a6791d9d8be/yin2013.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1179/146141010X12640787648892.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/2664/b25f73bab484851ed30a2de35e6526f0/vanneer2013.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1177/1461445613501444.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/4128/6652b42046657a5b941ac0dfef055673/10.1108@14637151211253792.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1039/c3cp90055j.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1039/C5CP04462F.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Nothing here!, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14639947.2017.1301032.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1111/bju.12913.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1111/mpp.12020.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Nothing here!, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14649357.2018.1501510.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/3219/dfb65a8ae503f20529c849041611e3d6/fannin2010.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14649365.2018.1455217.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14650045.2017.1309832.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:Nothing here!, retrying in 75 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1163/1569206X-12341269.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14656566.2016.1276564.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1057/thr.2009.35.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14680777.2017.1283343.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://twin.sci-hub.ru/7071/8e1d6608e58b2dc6ef3a80feb6ea668e/zembylas2018.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14685248.2017.1390239.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/3881/1d59f7048f6999f2fb808be8140fe535/farnsworth2010.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1177/1468796809354153.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14703297.2020.1752282.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Nothing here!, retrying in 75 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1504/IJMC.2018.089758.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/1054/a9ef11dda89e11b780d21810b8328388/silverman2010.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1038/nrn.2017.113.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/14712598.2020.1738378.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Nothing here!, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1016/j.it.2018.02.004.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://zero.sci-hub.st/
pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1302/2058-5241.4.180061.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1038/s41570-018-0119.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1038/s41893-020-00617-y.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.30965/24518921-00504005.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1016/j.chempr.2019.12.021.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Unknown issue!, retrying in 75 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-05-23/7c/10.1016@j.coesh.2020.05.002.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-05-23/7c/10.1016@j.coesh.2020.05.002.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-05-23/7c/10.1016@j.coesh.2020.05.002.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1126/sciimmunol.abd2591.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-12-05/fb/10.1126@sciimmunol.abd2591.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-08-11/19/samreen2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-08-11/19/samreen2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-08-11/19/samreen2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-08-12/8c/assen2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-08-12/8c/assen2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-08-12/8c/assen2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-28/48/miyamoto2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-28/48/miyamoto2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-28/48/miyamoto2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-21/1e67/frontmatter-2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-21/1e67/frontmatter-2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-21/1e67/frontmatter-2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1007/s41064-020-00114-z.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-07-23/08/peters2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-02-19/63/correction-drug-discovery-today-no-molecules-required-2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-02-19/63/correction-drug-discovery-today-no-molecules-required-2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-02-19/63/correction-drug-discovery-today-no-molecules-required-2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1353/neo.2015.0010.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-01-09/6b/smit2015.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1016/S2542-5196%252819%252930047-6.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2019-09-21/5e/xue2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2019-09-21/5e/xue2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/25739638.2020.1807733.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:can't read pdf, retrying in 5 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-01-08/28/myhre2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-01-08/28/myhre2019.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-16/a4/freeman2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-16/a4/freeman2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-16/a4/freeman2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2021-05-16/a4/freeman2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2020-11-02/a0/marzo-ortega2020.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1193/051214EQS067M.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:cant_connect_to Scihub, retrying in 75 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1016/j.compcom.2018.03.006.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: /downloads/2019-03-03/b8/10.1016@j.compcom.2019.01.007.pdf#navpanes=0&view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: https://sci.bban.top/pdf/10.1080/87559129.2013.790048.pdf#view=FitH, retrying in 15 seconds...
# WARNING:retry.api:Can't connect to direct URL: http://zero.sci-hub.st/2242/b4112059a4c256179d76fa1c514a7a57/sivakumar2013.pdf#navpanes=0&view=FitH, retrying in 15 seconds...

# %% [markdown]
# SumCetCet is also ready, the loop above is executed!

# %% [markdown]
# SumCetCet is completed, second_run_dates_dict can be created:

# %%
with open("ogi_dates_dict", "rb") as fp:
    ogi_dates_dict = pickle.load(fp)

with open("cet_dates_dict", "rb") as fp:
    cet_dates_dict = pickle.load(fp)

with open("sum_dates_dict", "rb") as fp:
    sum_dates_dict = pickle.load(fp)

# %%
ogi_dates_dict.update(cet_dates_dict)
ogi_dates_dict.update(sum_dates_dict)

# %%
second_run_dates_dict = ogi_dates_dict

with open("second_run_dates_dict","wb") as fp:
    pickle.dump(second_run_dates_dict, fp)

# %%
second_run_meta["Results"] = second_run_meta.DOI.map(second_run_dates_dict)

# %%
second_run_meta.Results.map(type).value_counts()
# Out:
# <class 'list'>    55778
# <class 'str'>     10332
# Name: Results, dtype: int64

# %%
len(second_run_meta)
# Out:
# 66110

# %%
second_run_date_df = second_run_meta.copy()

# %%
# %store second_run_date_df
# Out:
# Stored 'second_run_date_df' (DataFrame)

# %% [markdown]
# second_run_date_df is created and saved. This df will be merged with date_df in the next steps to create a singular df for all articles analysed so far.
#
# The only caveat is that this df will include "skipped" articles as well, which have metadata but did NOT go through sh.get_dates(), and thus did NOT complete the pipeline.
#
# These should be dropped!

# %% [markdown]
# ---
#
# As the final step of this notebook, jrnl_df(s) should also be ready for merging. So, second_run_df must aso have Results column to filter jrnls.
#
# This will be conducted below:

# %%
second_run_df.head()
# Out:
#           Issn  Year  Total_Docs  Sample_Count CrossRef_retr  \
# 0   [00011541]  2010         294             1          True
# 1   [00011541]  2011         315             1          True
# 2   [00011541]  2012         347             1          True
# 21  [00013765]  2020         363             1          True
# 22  [00014273]  2010          70             1          True
#
#                               DOI  \
# 0               10.1002/aic.12400
# 1               10.1002/aic.12671
# 2               10.1002/aic.13810
# 21  10.1590/0001-3675202020180560
# 22      10.5465/amj.2010.52814362
#
#                                               Results Second_CR_retr  \
# 0   [https://sci.bban.top/pdf/10.1002/aic.12400.pd...           True
# 1   [https://sci.bban.top/pdf/10.1002/aic.12671.pd...           True
# 2   [https://sci.bban.top/pdf/10.1002/aic.13810.pd...           True
# 21                              article_not_in Scihub           True
# 22  [https://sci.bban.top/pdf/10.5465/amj.2010.528...           True
#
#             2nd_Results
# 0   [10.1002/aic.12388]
# 1                    []
# 2                    []
# 21                   []
# 22                   []

# %% [markdown]
# During planning it is seen that, as there are multiple DOIs from a single journal; the process would require an unnecesarily long effort & run time. As a result, only successful (type==list & len==3) articles will be merged to second_run_df.
#
# The second run Journal dataset will therefore lack the information why the failed journals failed, BUT this is in no way important for the overall analysis.
#
# Article df (date_df + second_run_date_df) will have ALL the information, but the resulting Journal df will not.

# %%
def is_useful(resu):
    if type(resu) == list:
        if len(resu) == 3:
            return True
        else:
            return False
    else:
        return False

# %%
second_run_date_df["ISSN"] = second_run_date_df.ISSN.map(lambda x: [iss.replace("-","") for iss in x])
second_run_date_df["is_useful"] = second_run_date_df.Results.map(is_useful)

# %%
useful_2nd_date_df = second_run_date_df[second_run_date_df.is_useful == True][["ISSN","Year","DOI","Results"]].copy()

# %%
useful_2nd_date_df.shape
# Out:
# (5474, 4)

# %%
def doi_retr(retrrow, artcldf):
    issn = retrrow.Issn
    year = retrrow.Year
    doi = artcldf[(artcldf.ISSN.map(lambda x: any(iss in x for iss in issn))) & (artcldf.Year == year)]["DOI"].tolist()
    return doi

# %%
doi_retr_trial3 = second_run_df.apply(lambda x: doi_retr(x,useful_2nd_date_df), axis=1, result_type="reduce")

# %%
second_run_df["2nd_Results"] = doi_retr_trial3

# %%
second_run_df["2nd_Results"].map(len).value_counts()
# Out:
# 0    37955
# 1     5316
# 2       79
# Name: 2nd_Results, dtype: int64

# %% [markdown]
# 79 journals had different ISSNs returned, causing multiple article matches. These 79 duplicates will be dropped from second_run_date_df.

# %%
second_run_df[second_run_df["2nd_Results"].map(len)== 2]
# Out:
#                         Issn  Year  Total_Docs  Sample_Count CrossRef_retr  \
# 1132              [00063525]  2010         203             1          True
# 1137              [00063525]  2015         153             1          True
# 1339              [00072745]  2017          38             1          True
# 1476              [0008543X]  2018         606             1          True
# 2250              [00130427]  2018          34             1          True
# ...                      ...   ...         ...           ...           ...
# 68269             [20457758]  2019        1118             1          True
# 68517             [20483694]  2015          15             1          True
# 69074             [20556225]  2016          41             1          True
# 71047             [21911363]  2016          80             1          True
# 71104  [21922640,  21922659]  2017         302             1          True
#
#                                DOI  \
# 1132             10.1002/bip.21349
# 1137             10.1002/bip.22749
# 1339   10.1639/0007-2745-120.2.261
# 1476            10.1002/cncr.31630
# 2250            10.1111/ecca.12289
# ...                            ...
# 68269            10.1002/ece3.4324
# 68517              10.1002/fes3.53
# 69074    10.1108/jstp-01-2015-0013
# 71047       10.1002/open.201600032
# 71104       10.1002/adhm.201770035
#
#                                                  Results Second_CR_retr  \
# 1132   [https://sci.bban.top/pdf/10.1002/bip.21349.pd...           True
# 1137   [https://sci.bban.top/pdf/10.1002/bip.22749.pd...           True
# 1339   [https://sci.bban.top/pdf/10.1639/0007-2745-12...           True
# 1476   [https://sci.bban.top/pdf/10.1002/cncr.31630.p...           True
# 2250   [https://sci.bban.top/pdf/10.1111/ecca.12289.p...           True
# ...                                                  ...            ...
# 68269  [https://sci.bban.top/pdf/10.1002/ece3.4324.pd...           True
# 68517  [https://sci.bban.top/pdf/10.1002/fes3.53.pdf#...           True
# 69074  [https://sci.bban.top/pdf/10.1108/JSTP-01-2015...           True
# 71047  [https://sci.bban.top/pdf/10.1002/open.2016000...           True
# 71104  [https://sci.bban.top/pdf/10.1002/adhm.2017700...           True
#
#                                              2nd_Results
# 1132              [10.1002/bip.21312, 10.1002/bip.21384]
# 1137              [10.1002/bip.22740, 10.1002/bip.22581]
# 1339   [10.1639/0007-2745-120.3.311, 10.1639/0007-274...
# 1476            [10.1002/cncr.31570, 10.1002/cncr.31357]
# 2250            [10.1111/ecca.12271, 10.1111/ecca.12268]
# ...                                                  ...
# 68269             [10.1002/ece3.5209, 10.1002/ece3.4775]
# 68517                 [10.1002/fes3.65, 10.1002/fes3.64]
# 69074  [10.1108/jstp-09-2014-0190, 10.1108/jstp-12-20...
# 71047   [10.1002/open.201600048, 10.1002/open.201600066]
# 71104   [10.1002/adhm.201601411, 10.1002/adhm.201700254]
#
# [79 rows x 9 columns]

# %%
useful_dois = useful_2nd_date_df.DOI.tolist()

second_result_dois = [val for sublist in second_run_df["2nd_Results"].tolist() for val in sublist]

unmacthed_dois = set(useful_dois).difference(second_result_dois)

# %%
unmacthed_dois
# Out:
# set()

# %%
extra_dois = second_run_df[second_run_df["2nd_Results"].map(len)== 2]["2nd_Results"].map(lambda x: x[1]).tolist()

# %%
second_run_date_df.set_index("DOI",drop=True, inplace=True)
second_run_date_df.rename(columns={"references-count": "reference-count"},inplace=True)

# %%
second_run_date_df.drop("is_useful", axis=1, inplace=True)
second_run_date_df.drop(extra_dois,inplace=True)

# %%
useful_2nd_date_df.set_index("DOI",drop=True, inplace=True)
useful_2nd_date_df.drop(extra_dois,inplace=True)

# %%
second_run_df["2nd_Results"].map(len).value_counts()
# Out:
# 0    37955
# 1     5316
# 2       79
# Name: 2nd_Results, dtype: int64

# %%
# %store second_run_date_df
# %store second_run_df
