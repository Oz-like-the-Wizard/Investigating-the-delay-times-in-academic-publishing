# %%
import pandas as pd
import numpy as np
import pickle

from quartile_v2 import retr_ready

import random
# Out:
# b'Skipping line 32712: expected 20 fields, saw 21\nSkipping line 32713: expected 20 fields, saw 21\n'
# b'Skipping line 20760: expected 20 fields, saw 21\nSkipping line 22914: expected 20 fields, saw 21\n'
# b'Skipping line 19393: expected 20 fields, saw 21\nSkipping line 19394: expected 20 fields, saw 21\n'
# b'Skipping line 33757: expected 20 fields, saw 21\n'
# b'Skipping line 19053: expected 20 fields, saw 21\nSkipping line 20953: expected 20 fields, saw 21\n'

# %% [markdown]
# ## Part 1: Sample Count Calc. Function

# %%
def samp_calc(pop, z=1.96, moe=.04, p=.5):
    s = z**2 * p * (1-p) / moe**2

    adjs = s / (1+((s-1)/pop))

    return round(adjs)

# %%
samp_calc(700)
# Out:
# 323

# %% [markdown]
# ## Part 2: Sample Count Matrices

# %%
with open("q1_jrnl_df", "rb") as fp:
    q1_jrnl_df = pickle.load(fp)

with open("q2_jrnl_df", "rb") as fp:
    q2_jrnl_df = pickle.load(fp)

# %%
with open("q1_date_df", "rb") as fp:
    q1_date_df = pickle.load(fp)

with open("q2_date_df", "rb") as fp:
    q2_date_df = pickle.load(fp)

# %% [markdown]
# #### ARTICLES - Sample Size

# %%
q1_jrnl_expladed, q1_a_td, q1_a_sh, q1_a_cr = retr_ready(q1_jrnl_df)

# %% [markdown]
# Here:
#
# * __q1_jrnl_expladed__ -> expladed q1_jnrl_df
#
# * __q1_a_td__ -> "Total Docs" matrix for Q1 articles
#
#     * __q1_a_ss__ ->  _q1_a_tc.applymap(samp_calc)_ -> Sample size matrix for Q1 articles
#     *
#
# * __q1_a_sh__ -> "Total Docs" matrix for SH_Results ==True Q1 articles
#
# * __q1_a_cr__ -> "CR_Count" matrix for Q1 articles (CrossRef)
#
# * __q1_a_cr - q1_artcl_ss__ -> Negative = PROBLEM!

# %%
q1_a_ss = q1_a_td.applymap(samp_calc)
q1_a_ss
# Out:
# Year                                          2010  2011  2012  2013  2014  \
# Sbj_Area
# Agricultural and Biological Sciences           593   593   594   595   595
# Arts and Humanities                            581   583   585   586   587
# Biochemistry, Genetics and Molecular Biology   595   595   596   596   596
# Business, Management and Accounting            564   568   569   569   569
# Chemical Engineering                           578   580   582   585   587
# Chemistry                                      592   593   594   594   594
# Computer Science                               582   585   586   585   587
# Decision Sciences                              474   479   499   500   504
# Dentistry                                      524   535   537   536   539
# Earth and Planetary Sciences                   588   589   589   590   591
# Economics, Econometrics and Finance            546   549   556   554   555
# Energy                                         571   575   576   579   582
# Engineering                                    594   595   595   595   596
# Environmental Science                          586   587   588   589   590
# Health Professions                             554   556   557   560   561
# Immunology and Microbiology                    574   576   577   577   576
# Materials Science                              592   593   594   594   594
# Mathematics                                    583   586   586   586   585
# Medicine                                       599   599   599   599   599
# Multidisciplinary                              569   569   571   575   580
# Neuroscience                                   576   578   579   579   579
# Nursing                                        569   567   570   571   571
# Pharmacology, Toxicology and Pharmaceutics     583   586   587   585   586
# Physics and Astronomy                          594   595   595   595   595
# Psychology                                     566   569   571   576   578
# Social Sciences                                590   591   591   592   593
# Veterinary                                     540   541   547   546   542
#
# Year                                          2015  2016  2017  2018  2019  \
#
# Year                                            2014    2015    2016    2017  \
# Sbj_Area
# Agricultural and Biological Sciences           48001   49890   50554   50589
# Arts and Humanities                             9554    6341    8976    8387
# Biochemistry, Genetics and Molecular Biology   63962   56406   57655   54783
# Business, Management and Accounting             5699    6546    7217    7059
# Chemical Engineering                           15852   15868   14325   15048
# Chemistry                                      39872   38245   36907   32692
# Computer Science                               20844   20903   23656   24889
# Decision Sciences                               2148    2187    2421    2305
# Dentistry                                       1269    1240    1205    2487
# Earth and Planetary Sciences                   27428   26972   28133   28348
# Economics, Econometrics and Finance             3113    3721    3177    3779
# Energy                                         15188   15436   18017   16629
# Engineering                                    63286   64608   72828   76377
# Environmental Science                          26006   25901   27584   25700
# Health Professions                              3160    3146    3906    3765
# Immunology and Microbiology                    10633    8085    8477    9772
# Materials Science                              41798   40542   49573   41041
# Mathematics                                    15489   16655   19051   16674
# Medicine                                      185128  177027  183420  186566
# Multidisciplinary                               7824   13154   24094   27976
# Neuroscience                                    9035    9780   10122   12153
# Nursing                                         4720    6607    4476    5787
# Pharmacology, Toxicology and Pharmaceutics     11618   10855   11704   12266
# Physics and Astronomy                          53667   46876   55253   50151
# Psychology                                      8701    9486   10485    9283
# Social Sciences                                18187   19963   22252   24627
# Veterinary                                      2575    2579    2969    2860
#
# Year                                            2018    2019    2020
# Sbj_Area
# Agricultural and Biological Sciences           50394   53870   62037
# Arts and Humanities                            12408   13368   15675
# Biochemistry, Genetics and Molecular Biology   50593   54866   56925
# Business, Management and Accounting             8697   11726   12830
# Chemical Engineering                           18212   20666   23559
# Chemistry                                      37093   45075   57826
# Computer Science                               30936   37500   46210
# Decision Sciences                               2796    2782    3798
# Dentistry                                       1798    2472    2937
# Earth and Planetary Sciences                   31420   34443   38472
# Economics, Econometrics and Finance             4657    5817    7703
# Energy                                         19368   21627   27929
# Engineering                                    88935  100994  103783
# Environmental Science                          35832   38880   43985
# Health Professions                              2762    3451    5392
# Immunology and Microbiology                    10189   10499   12560
# Materials Science                              48043   47253   65368
# Mathematics                                    18923   19563   21001
# Medicine                                      183805  197595  227418
# Multidisciplinary                              29933   44293   53691
# Neuroscience                                    9741    9616   10124
# Nursing                                         6470    7560   11271
# Pharmacology, Toxicology and Pharmaceutics     14701   20838   20647
# Physics and Astronomy                          58255   53005   57317
# Psychology                                     10764   10875    9284
# Social Sciences                                28310   37164   55589
# Veterinary                                      3684    5068    8279

# %% [markdown]
# It is seen that, the number of articles available are more than enough to satisfy the sample size requirements. GOOD NEWS!

# %% [markdown]
# ### JOURNALS - Sample Size

# %%
# JOURNAL - TOTAL COUNT:
q1_j_tc = pd.pivot_table(data=q1_jrnl_expladed, columns="Year", index="Sbj_Area", values="Total_Docs", aggfunc="count")

# JOURNAL - SAMPLE SIZE:
q1_j_ss = q1_j_tc.applymap(samp_calc)

# JOURNAL - AVAILABLE:
q1_j_a = pd.pivot_table(data=q1_jrnl_expladed[q1_jrnl_expladed.SH_Results == True], columns="Year", index="Sbj_Area", values="Total_Docs", aggfunc="count")

# %% [markdown]
# Here:
#
# * __q1_j_tc__ -> Total count for Q1 journals
#
# * __q1_j_ss__ -> Sample size for Q1 journals
#
# Physics and Astronomy                            8
# Psychology                                       0
# Social Sciences                                242
# Veterinary                                       0

# %% [markdown]
# Unfortunately, the sample size for journals are greater than the number of available journals for some subject areas.
#
#
#
# This is because the articles can be compansated by using DATE_AVAILABLE journal articles,
#
# BUT DATE_AVAILABLE journals are in the minority & cant be compansated elsewhere.
#
# ___ASKED BRUNO FOR ADVICE, WILL MOVE ON FOR NOW!___
#
# Will make a note of problematic S_A during writing!

# %% [markdown]
# ## PART 3: Sample_Count Column

# %% [markdown]
# After some analysis, it is decided that one article will be included by default for each artcl/s_a
#
# Therefore, all the articles retrieved so far can be utilized efficiently & maximum number of jorunals are inclueded for each cell!
#
# As seen from below, only Medicine & Social Sciences (2020) have more jrnls than articles necessary. However, as most Medicine journals have multiple subject areas, the extras can count towards the remaining subject areas. This will be clear once Sample Size per journal is calculated.

# %%
q1_a_ss - q1_j_a
# Out:
# Year                                          2010  2011  2012  2013  2014  \
# Sbj_Area
# Agricultural and Biological Sciences           278   294   271   246   235
# Arts and Humanities                            471   464   444   449   417
# Biochemistry, Genetics and Molecular Biology   323   309   308   298   288
# Business, Management and Accounting            467   469   465   468   450
# Chemical Engineering                           485   491   492   492   494
# Chemistry                                      457   463   465   452   457
# Computer Science                               391   384   383   374   361
# Decision Sciences                              429   432   450   451   449
# Dentistry                                      505   517   517   518   520
# Earth and Planetary Sciences                   410   415   412   400   390
# Economics, Econometrics and Finance            475   480   480   484   482
# Energy                                         506   512   511   506   509
# Engineering                                    204   193   178   159   156
# Environmental Science                          413   417   394   381   385
# Health Professions                             511   514   512   510   514
# Immunology and Microbiology                    519   510   509   505   501
# Materials Science                              392   397   394   388   393
# Mathematics                                    416   403   395   384   376
# Medicine                                      -185  -197  -236  -287  -308
# Multidisciplinary                              561   560   561   564   566
# Neuroscience                                   517   513   507   506   503
# Nursing                                        518   513   515   516   515
# Pharmacology, Toxicology and Pharmaceutics     492   495   495   492   491
# Physics and Astronomy                          428   423   418   408   416
# Psychology                                     452   472   462   461   457
# Social Sciences                                329   325   298   263   242
# Veterinary                                     511   518   520   518   512
#
# Year                                          2015  2016  2017  2018  2019  \
# Sbj_Area
# Agricultural and Biological Sciences           222   225   225   209   185
# Arts and Humanities                            431   407   396   373   353
# Biochemistry, Genetics and Molecular Biology   286   270   305   305   280
# Business, Management and Accounting            440   441   437   415   387
# Chemical Engineering                           497   502   502   494   485
# Chemistry                                      462   457   478   483   457
# Computer Science                               354   346   342   330   317
# Decision Sciences                              444   454   458   458   460
# Dentistry                                      519   519   520   522   521
# Earth and Planetary Sciences                   397   393   398   382   386
# Economics, Econometrics and Finance            475   474   468   460   448
# Energy                                         510   509   517   513   506
# Engineering                                    146   152   145   116    80
# Environmental Science                          373   380   382   358   337
# Health Professions                             508   508   510   513   507
# Immunology and Microbiology                    506   509   504   510   500
# Materials Science                              385   377   389   378   359
# Mathematics                                    362   360   360   353   349
# Medicine                                      -301  -333  -301  -309  -355
# Multidisciplinary                              569   576   574   572   575
# Neuroscience                                   508   497   501   504   506
# Nursing                                        516   514   512   507   507
# Pharmacology, Toxicology and Pharmaceutics     487   483   478   484   472
# Physics and Astronomy                          411   404   406   408   401
# Psychology                                     449   451   461   457   460
# Social Sciences                                214   171   127    90     2
# Veterinary                                     517   512   510   515   517
#
# Year                                          2020
# Sbj_Area
# Agricultural and Biological Sciences           185
# Arts and Humanities                            320
# Biochemistry, Genetics and Molecular Biology   299
# Business, Management and Accounting            390
# Chemical Engineering                           487
# Chemistry                                      455
# Computer Science                               305
# Decision Sciences                              476
# Dentistry                                      524
# Earth and Planetary Sciences                   384
# Economics, Econometrics and Finance            445
# Energy                                         498
# Engineering                                     85
# Environmental Science                          337
# Health Professions                             500
# Immunology and Microbiology                    502
# Materials Science                              356
# Mathematics                                    349
# Medicine                                      -369
# Multidisciplinary                              574
# Neuroscience                                   505
# Nursing                                        497
# Pharmacology, Toxicology and Pharmaceutics     482
# Physics and Astronomy                          406
# Psychology                                     446
# Social Sciences                                -80
# Veterinary                                     529

# %% [markdown]
# ### THE WAY FORWARD:
#
# The best course of action is decided to be:
#
# Get 1 ARTICLE per JOURNAL/S_A (q1a), so that the __maximum number of journals is ensured!__
#
# Then we can only use the article matrix (q1_artl_ss) (minus the current available articles) during sample size extraction!
#
#
#
# So:
#
# 1- Add a s_a column to q1_date_df - DONE!
#
# 2- Merge this column to q1a, so we have a current count column - DONE!
#
# 3- Create a pivot from this column (current_count) to calculate the current status pivot
#
#     3.5- substract from q1_artcl_ss to find missing & required artcl number
#
# 4- Randomly allocate these required artcl to appropriate journals
#
# 5- CR + SH loops for the allocated number of artcls for each jrnl
#
# 6- FINISH!!!
#
# PS. any extra artcls (esp. for Medicine) can be dropped later on, as they are already extracted & will have a s_a column!

# %%
# Part 1:

def sa_finder(id):
    return random.choice(list(q1_jrnl_df.loc[id,"Sbj_Area"]))


q1_date_df["S_A"] = q1_date_df.JRNL_ID.map(sa_finder)

# %%
q1_date_df.groupby(["JRNL_ID", "S_A"]).title.count().value_counts()
# Out:
# 1    34211
# 2       54
# Name: title, dtype: int64

# %%
# Part 2:

q1_jrnl_expladed = pd.merge(left=q1_jrnl_expladed, right=q1_date_df.groupby(["JRNL_ID", "S_A"]).title.count(), left_on=["ID","Sbj_Area"], right_index=True, how="left")

q1_jrnl_expladed.rename(columns={"title": "Current_Count"}, inplace=True)

q1_jrnl_expladed['Current_Count'] =  q1_jrnl_expladed['Current_Count'].fillna(0).map(int)

# %%
q1_jrnl_expladed.head()
# Out:
#      ID                  ISSN  Year           Sbj_Area  SH_Results  CR_Count  \
# 0  1_11  (00013765, 16782690)  2018  Multidisciplinary        True       294
# 1  1_12  (00013765, 16782690)  2019  Multidisciplinary        True       305
# 2  1_13  (00013765, 16782690)  2020  Multidisciplinary       False       363
# 3  1_14  (00013765, 16782690)  2010  Multidisciplinary        True       101
# 4  1_15  (00013765, 16782690)  2016  Multidisciplinary        True       204
#
#    Total_Docs  Current_Count
# 0         307              1
# 1         307              1
# 2         363              0
# 3         100              1
# 4         205              1

# %%
q1_jrnl_expladed[q1_jrnl_expladed.SH_Results == True ].groupby("ID").Current_Count.sum().value_counts()

# It is seen that 196 journals do not have any articles currently! This must be fixed to ensure maximum jnrl inclusion!
# Out:
# 1    34165
# 0      196
# 2       77
# Name: Current_Count, dtype: int64

# %%
# The solution is to add a Current_Count column to q1_jnrl_df so that we can determine the missing jrnls
q1_jrnl_df["Current_Count"] = q1_jrnl_expladed[q1_jrnl_expladed.SH_Results == True ].groupby("ID").Current_Count.sum()


# Next, add Required_Count column to q1_jrnl_df
q1_jrnl_df["Required_Count"] = 0


# & +1 to each missing jnrl GIVEN THAT they are NOT medicine journals
q1_jrnl_df.loc[(q1_jrnl_df.Current_Count == 0) & (q1_jrnl_df.Sbj_Area.map(lambda x: "Medicine" not in x)),"Required_Count"] = 1


#  Finally use ID & Sbj_Area random choice to create Required_Count column on q1_jrnl_expladed as well
for ind, row in q1_jrnl_df[q1_jrnl_df.Required_Count == 1].iterrows():
    s_a = random.choice(list(row["Sbj_Area"]))

    q1_jrnl_expladed.loc[(q1_jrnl_expladed.ID == ind) & (q1_jrnl_expladed.Sbj_Area == s_a), "Required_Count"] = 1

# %%
q1_jrnl_df["Required_Count"].value_counts()
# Out:
# 0    66812
# 1      104
# Name: Required_Count, dtype: int64

# %%
q1_jrnl_df[q1_jrnl_df.SH_Results == False][["Current_Count","Required_Count"]].sum()
# Out:
# Current_Count     0.0
# Required_Count    0.0
# dtype: float64

# %%
q1_jrnl_expladed[q1_jrnl_expladed.SH_Results == False][["Current_Count","Required_Count"]].sum()
# Out:
# Current_Count     0
# Required_Count    0
# dtype: int64

# %% [markdown]
# Journal related issues should be all accounted for. Can create a current + required pivot
#
# Use this pivot to substract from q1_a_ss to get the final initial pivot
#
# Loop through each cell & random choice & +1 Req_Count to each selected

# %%
q1_a_current = pd.pivot_table(data=q1_jrnl_expladed, columns="Year", index="Sbj_Area", values="Current_Count", aggfunc=sum)

q1_a_required = pd.pivot_table(data=q1_jrnl_expladed, columns="Year", index="Sbj_Area", values="Required_Count", aggfunc=sum)

q1_a_initial = q1_a_required + q1_a_current

q1_a_ss_init = q1_a_ss- q1_a_initial

# %% [markdown]
# Create a function that iterates each cell of above &
#
# - if >0:
# - filter q1_jrnl_expladed
# - for in range(required):
# - while req_count < CR_Count
# - choose a row
# -  +=1 to req_count

# %%
with open("q1_jrnl_expladed","wb") as p:
    pickle.dump(q1_jrnl_expladed, p)

# %%
with open("q1_jrnl_expladed", "rb") as fp:
    q1_jrnl_expladed = pickle.load(fp)

# %%
for s_a, row in q1_a_ss_init.iterrows(): #iterate over rows
    for year, value in row.items():
        if value < 0:
            pass
        else:
            for i in range(value):
                # select one: 
                sampl_ind = q1_jrnl_expladed[(q1_jrnl_expladed.SH_Results == True) & (q1_jrnl_expladed.Year == year) & (q1_jrnl_expladed.Sbj_Area == s_a) & (q1_jrnl_expladed.Current_Count + q1_jrnl_expladed.Required_Count < q1_jrnl_expladed.CR_Count)].sample(1).index
                sampl_rc = q1_jrnl_expladed.loc[sampl_ind, "Required_Count"]
                sampl_rc += 1
                q1_jrnl_expladed.loc[sampl_ind, "Required_Count"] = sampl_rc

# %%
q1_a_required_after = pd.pivot_table(data=q1_jrnl_expladed, columns="Year", index="Sbj_Area", values="Required_Count", aggfunc=sum)

# %% [markdown]
# THE LOOP IS COMPLETE AND THE REQUIRED COUNT COLUMN IS READY FOR DATA EXTRACTION!
#
# Only we need to check if q1_jrnl_df Required Count is < CR_Count, as the filter was for expladed & we might have exceeded the threshold for the total jrnl.

# Environmental Science                            0
# Health Professions                               0
# Immunology and Microbiology                      0
# Materials Science                                0
# Mathematics                                      0
# Medicine                                      -111
# Multidisciplinary                                0
# Neuroscience                                     0
# Nursing                                          0
# Pharmacology, Toxicology and Pharmaceutics       0
# Physics and Astronomy                            0
# Psychology                                       0
# Social Sciences                                  0
# Veterinary                                       0

# %% [markdown]
# Also, after the extraction loop may need to drop these extra Medicine articles! Will leave for now!

# %% [markdown]
# ### NEXT STEPS:
#
# - Calc. sample count for Q2 jnrls as well (can repeat the same steps as Q1)
#
# - Deal with problematic 13 jrnls (prob. manually)
#
# - Create SumCetCet loop for Q1 final extraction!

# %%
with open("q1_jrnl_expladed","wb") as p:
    pickle.dump(q1_jrnl_expladed, p)

with open("q1_jrnl_df","wb") as p:
    pickle.dump(q1_jrnl_df, p)

# %% [markdown]
# ### Fixing the problematic 13 journals:

# %% [markdown]
# After some consideration, it is decided to just eliminate the problematic journals, as there will most probably be other issues (such as duplicate articles) during final extraction phase. Dealing with all of them together will be less time consuming (hopefully)!

# %%
prb_13 = q1_jrnl_df[q1_jrnl_df.CR_Count<q1_jrnl_df.Required_Count].index.tolist()

# %%
print(prb_13)
# Out:
# ['1_26754', '1_26808', '1_26814', '1_27066', '1_27067', '1_27074', '1_27169', '1_27175', '1_49259', '1_49674', '1_54183', '1_54184', '1_61661']

# %%
q1_jrnl_expladed.loc[q1_jrnl_expladed.ID.map(lambda x: x in prb_13), "Required_Count"] = 0

# %% [markdown]
# q1_jrnl_df[q1_jrnl_df.CR_Count<q1_jrnl_df.Required_Count]

# %%
q1_jrnl_df.loc[q1_jrnl_df.CR_Count<q1_jrnl_df.Required_Count, "Required_Count"] = 0
# Out:
# ID
# 1_26754    2
# 1_26808    5
# 1_26814    3
# 1_27066    3
# 1_27067    7
# 1_27074    2
# 1_27169    3
# 1_27175    9
# 1_49259    4
# 1_49674    3
# 1_54183    6
# 1_54184    2
# 1_61661    2
# Name: Required_Count, dtype: int64

# %%
q1_jrnl_expladed[q1_jrnl_expladed.Required_Count != 0]
# Out:
#              ID                  ISSN  Year           Sbj_Area  SH_Results  \
# 0          1_11  (00013765, 16782690)  2018  Multidisciplinary        True
# 1          1_12  (00013765, 16782690)  2019  Multidisciplinary        True
# 3          1_14  (00013765, 16782690)  2010  Multidisciplinary        True
# 4          1_15  (00013765, 16782690)  2016  Multidisciplinary        True
# 5          1_16  (00013765, 16782690)  2017  Multidisciplinary        True
# ...         ...                   ...   ...                ...         ...
# 100845  1_66910  (8756758X, 14602695)  2014        Engineering        True
# 100846  1_66911  (8756758X, 14602695)  2017  Materials Science        True
# 100848  1_66912  (8756758X, 14602695)  2016  Materials Science        True
# 100852  1_66914  (8756758X, 14602695)  2015  Materials Science        True
# 100853  1_66914  (8756758X, 14602695)  2015        Engineering        True
#
#         CR_Count  Total_Docs  Current_Count  Required_Count
# 0            294         307              1              37
# 1            305         307              1              23
# 3            101         100              1             100
# 4            204         205              1              53
# 5            268         256              1              47
# ...          ...         ...            ...             ...
# 100845        90          79              0               1
# 100846        64          56              1               2
# 100848        58          40              1               2
# 100852        36          43              0               6
# 100853        73          86              1               1
#
# [35741 rows x 9 columns]
