# %%
import pandas as pd
import numpy as np
import pickle

from crossref.restful import Works, Etiquette
#from scihub_blastoise import SciHub_HydroPump

# %%
with open("q1_jrnl_expladed", "rb") as fp:
    q1_jrnl_expladed = pickle.load(fp)

with open("q1_jrnl_df", "rb") as fp:
    q1_jrnl_df = pickle.load(fp)

# %% [markdown]
# __NOTE:__ Before the loop, it is realised that using q1_jrnl_df during the loop will prevent duplicate article extraction by a HUGE margin. therefore, although it will be double-work, it makes much more sense to use it & attach s_a info to articles after the extraction is completed!
#
# TTD:
#
# * Need to convert ISSN colm to list - DONE - in SumCetCet below
# * Need to update useful_cols - DONE - only removed "reference" column
# * In addition to prob.13, there are 44 journals that exceed their CR_Count when the Current_Count is also considered. Fortunately, this is also a very low minority when the total dataset is considered, but still neeeds to be accounted for! - SKIPPED - will deal with later

# %%
# TTD #2:
with open("q1_date_df", "rb") as fp:
    q1_date_df = pickle.load(fp)

print(q1_date_df.columns)

useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'container-title', 'issued', 'ISSN', 'subject']
# Out:
# Index(['JRNL_ID', 'ISSN', 'issued', 'container-title', 'publisher', 'title',
#        'author', 'subject', 'references-count', 'is-referenced-by-count',
#        'published', 'published-print', 'published-online', 'direct_url',
#        'Dates', 'Keywords', 'Affiliation'],
#       dtype='object')

# %%
# TTD #3:
q1_jrnl_df[q1_jrnl_df.Required_Count + q1_jrnl_df.Current_Count > q1_jrnl_df.CR_Count]

# %%
# Test Run:

# SumCetCet CR Loop Run (for q1_jrnl_fe):

from crossref.restful import Works, Etiquette

testo = q1_jrnl_fe.sample(5)
print(testo.Required_Count.sum())


my_etiquette = Etiquette('Analysing Publishing Delay in Academic Journals', 'v2.0', 'https://github.com/Spidey0023/THEsis-Codes', 'oguzkokes@gmail.com')

ogi_works = Works(etiquette=my_etiquette)

q1_dict = testo[["ISSN","Year", "Required_Count"]].to_dict("index")

#Need to convert ISSN column to list!!!


cet_q1_meta_fe = []
useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'container-title', 'issued', 'ISSN', 'subject']


for key in q1_dict:
    issn = q1_dict[key]["ISSN"]
    year = q1_dict[key]["Year"]
    rc = q1_dict[key]["Required_Count"]

    loop_meta = [w for w in ogi_works.filter(issn=list(issn), from_pub_date=year, until_pub_date=year, type="journal-article").sample(int(rc)).select(useful_cols)] 
    loop_meta = [dict(item, JRNL_ID=key) for item in loop_meta]
        
    cet_q1_meta_fe.extend(loop_meta)


# open("cet_q1_meta_fe","wb") as fp:
#    pickle.dump(cet_q1_meta_fe, fp)

# %% [markdown]
# Test run is succesful! Will move on to the SumCetCet run!

# %%
# SumCetCet CR Loop Run (for q1_jrnl_fe):

from crossref.restful import Works, Etiquette
import pandas as pd
import pickle

with open("q1_jrnl_df", "rb") as fp:
    q1_jrnl_df = pickle.load(fp)

# Filtering only necessary jrnls:
q1_jrnl_fe = q1_jrnl_df[q1_jrnl_df.Required_Count >0].copy()
q1_jrnl_fe["ISSN"] = q1_jrnl_fe.ISSN.map(list)

#SumCetCet division:
q1_cr_sum = q1_jrnl_fe[:7000]
q1_cr_cet = q1_jrnl_fe[70000:170000]
q1_cr_ogi = q1_jrnl_fe[170000:]

mail = ""
# 'sduzenli@yandex.com.tr'
# 'cetiner.mserdar@gmail.com'
# 'oguzkokes@gmail.com'

my_etiquette = Etiquette('Analysing Publishing Delay in Academic Journals', 'v2.0', 'https://github.com/Spidey0023/THEsis-Codes', mail)


ogi_works = Works(etiquette=my_etiquette)

q1_dict = q1_cr_cet[["ISSN","Year", "Required_Count"]].to_dict("index")


cet_q1_meta_fe = []
useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'container-title', 'issued', 'ISSN', 'subject']


for key in q1_dict:
    issn = q1_dict[key]["ISSN"]
    year = q1_dict[key]["Year"]
    rc = q1_dict[key]["Required_Count"]

    loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(rc).select(useful_cols)] 
    loop_meta = [dict(item, JRNL_ID=key) for item in loop_meta]
        
    cet_q1_meta_fe.extend(loop_meta)


with open("cet_q1_meta_fe","wb") as fp:
    pickle.dump(cet_q1_meta_fe, fp)

# %%
# Ogi CR Loop Run (for q1_jrnl_fe):

from crossref.restful import Works, Etiquette
import pandas as pd
import pickle

with open("q1_jrnl_df", "rb") as fp:
    q1_jrnl_df = pickle.load(fp)

# Filtering only necessary jrnls:
q1_jrnl_fe = q1_jrnl_df[q1_jrnl_df.Required_Count >0].copy()
q1_jrnl_fe["ISSN"] = q1_jrnl_fe.ISSN.map(list)

#SumCetCet division:
q1_cr_ogi = q1_jrnl_fe[17000:]


mail = 'oguzkokes@gmail.com'
my_etiquette = Etiquette('Analysing Publishing Delay in Academic Journals', 'v2.0', 'https://github.com/Spidey0023/THEsis-Codes', mail)
ogi_works = Works(etiquette=my_etiquette)

q1_dict = q1_cr_ogi[["ISSN","Year", "Required_Count"]].to_dict("index")


ogi_q1_meta_fe = []

useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'container-title', 'issued', 'ISSN', 'subject']

for key in q1_dict:
    issn = q1_dict[key]["ISSN"]
    year = q1_dict[key]["Year"]
    rc = q1_dict[key]["Required_Count"]

    loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(rc).select(useful_cols)] 
    loop_meta = [dict(item, JRNL_ID=key) for item in loop_meta]
        
    ogi_q1_meta_fe.extend(loop_meta)


with open("ogi_q1_meta_fe","wb") as fp:
    pickle.dump(ogi_q1_meta_fe, fp)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-a4cdaeaacb7c> in <module>
#      32     rc = q1_dict[key]["Required_Count"]
#      33
# ---> 34     loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(rc).select(useful_cols)]
#      35     loop_meta = [dict(item, JRNL_ID=key) for item in loop_meta]
#      36
#
# <ipython-input-1-a4cdaeaacb7c> in <listcomp>(.0)
#      32     rc = q1_dict[key]["Required_Count"]
#      33
# ---> 34     loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(rc).select(useful_cols)]
#      35     loop_meta = [dict(item, JRNL_ID=key) for item in loop_meta]
#      36
#
# c:\Users\oguzk\anaconda3\lib\site-packages\crossref\restful.py in __iter__(self)
#     268                 raise StopIteration()
#     269
# --> 270             result = result.json()
#     271
#     272             for item in result['message']['items']:
#
# c:\Users\oguzk\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# c:\Users\oguzk\anaconda3\lib\site-packages\simplejson\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     523             parse_constant is None and object_pairs_hook is None
#     524             and not use_decimal and not kw):
# --> 525         return _default_decoder.decode(s)
#     526     if cls is None:
#     527         cls = JSONDecoder
#
# c:\Users\oguzk\anaconda3\lib\site-packages\simplejson\decoder.py in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, bytes):
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# c:\Users\oguzk\anaconda3\lib\site-packages\simplejson\decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# An error occured after JRNL 1_49971, will continue loop from this point on!

# %%
# DUMPing ogi_q1_meta_fe just in case:

with open("ogi_q1_meta_fe","wb") as fp:
    pickle.dump(ogi_q1_meta_fe, fp)

# %%
# Cont. after error:

q1_dict = q1_cr_ogi.loc["1_49971":,["ISSN","Year", "Required_Count"]].to_dict("index")

useful_cols = ['DOI', 'references-count', 'publisher', 'published-print', 'is-referenced-by-count', 'title', 'author', 'published-online', 'container-title', 'issued', 'ISSN', 'subject']

for key in q1_dict:
    issn = q1_dict[key]["ISSN"]
    year = q1_dict[key]["Year"]
    rc = q1_dict[key]["Required_Count"]

    loop_meta = [w for w in ogi_works.filter(issn=issn, from_pub_date=year, until_pub_date=year, type="journal-article").sample(rc).select(useful_cols)] 
    loop_meta = [dict(item, JRNL_ID=key) for item in loop_meta]
        
    ogi_q1_meta_fe.extend(loop_meta)


with open("ogi_q1_meta_fe","wb") as fp:
    pickle.dump(ogi_q1_meta_fe, fp)

# %% [markdown]
# NOTE: The "problematic" journal is duplicated, so need to drop half the extracred artlcs after the run is completed!

# %%
q1_jrnl_fe[17000:].Required_Count.sum()
# Out:
# 42992

# %% [markdown]
# ## Part 2: After SumCetCet FE - CrossRef Run

# %% [markdown]
# SumCetCet run is complete will now load all fe dfs & analyze results:

# %%
with open("sum_q1_meta_fe", "rb") as fp:
    sum_q1_meta_fe = pickle.load(fp)

with open("cet_q1_meta_fe", "rb") as fp:
    cet_q1_meta_fe = pickle.load(fp)

# with open("cet_q1_meta_fe", "rb") as fp:
#     cet_q1_meta_fe = pickle.load(fp)

# %%
q1_cr_sum = q1_jrnl_fe[:7000]
q1_cr_cet = q1_jrnl_fe[7000:17000]
# q1_cr_ogi = q1_jrnl_fe[170000:]

# %%
# Sum Analysis:

print(f"Required Count: {q1_cr_sum.Required_Count.sum()}")

print(f"Extracted Count: {len(sum_q1_meta_fe)}")
# Out:
# Required Count: 41367
# Extracted Count: 41367

# %%
# Cet Analysis:

print(f"Required Count: {q1_cr_cet.Required_Count.sum()}")

print(f"Extracted Count: {len(cet_q1_meta_fe)}")

print(f"Difference: {53907-53836}")
# Out:
# Required Count: 53907
# Extracted Count: 53836
# Difference: 71

# %%
# Ogi Analysis:

print(f"Required Count: {q1_cr_ogi.Required_Count.sum()}")

print(f"Extracted Count: {len(ogi_q1_meta_fe)}")

print(f"Difference: {42992-42981}")
# Out:
# Required Count: 42992
# Extracted Count: 42981
# Difference: 11

# %%
q1_meta_fe = pd.concat([pd.DataFrame(sum_q1_meta_fe),pd.DataFrame(cet_q1_meta_fe),pd.DataFrame(ogi_q1_meta_fe)], ignore_index=True)

# %%
q1_meta_fe.head()
# Out:
#   publisher              published-print                DOI  \
# 0     Wiley  {'date-parts': [[2013, 6]]}  10.1002/aic.13989
# 1     Wiley  {'date-parts': [[2014, 1]]}  10.1002/aic.14236
# 2     Wiley  {'date-parts': [[2013, 2]]}  10.1002/aic.13983
# 3     Wiley  {'date-parts': [[2013, 6]]}  10.1002/aic.14123
# 4     Wiley  {'date-parts': [[2014, 1]]}  10.1002/aic.14283
#
#    is-referenced-by-count                                              title  \
# 0                       9  [Liquid Fuels from Alternative Carbon Sources ...
# 1                      29  [Microwave irradiated and thermally heated oli...
# 2                       6  [Efficiency of Nitrogen Desorption from LiX Ze...
# 3                       3  [Celebrating singularities: Mathematics and ch...
# 4                      12  [Co-firing technology for the preparation of a...
#
#                                               author  \
# 0  [{'given': 'Matthew J.', 'family': 'Metzger', ...
# 1  [{'given': 'Tamer M.', 'family': 'Alslaibi', '...
# 2  [{'given': 'Siew Wah', 'family': 'Chai', 'sequ...
# 3  [{'given': 'Yunshan', 'family': 'Wang', 'seque...
# 4  [{'given': 'U.', 'family': 'Pippardt', 'sequen...
#
#                    published-online  container-title  \
# 0   {'date-parts': [[2013, 2, 19]]}  [AIChE Journal]
# 1   {'date-parts': [[2013, 10, 8]]}  [AIChE Journal]
# 2    {'date-parts': [[2013, 1, 3]]}  [AIChE Journal]
# 3    {'date-parts': [[2013, 5, 8]]}  [AIChE Journal]
# 4  {'date-parts': [[2013, 11, 19]]}  [AIChE Journal]
#
#                              issued  references-count         ISSN  \
# 0   {'date-parts': [[2013, 2, 19]]}                50  [0001-1541]
# 1   {'date-parts': [[2013, 10, 8]]}                52  [0001-1541]
# 2    {'date-parts': [[2013, 1, 3]]}                10  [0001-1541]
# 3    {'date-parts': [[2013, 5, 8]]}                62  [0001-1541]
# 4  {'date-parts': [[2013, 11, 19]]}                20  [0001-1541]
#
#                                              subject JRNL_ID
# 0  [General Chemical Engineering, Environmental E...     1_0
# 1  [General Chemical Engineering, Environmental E...     1_0
# 2  [General Chemical Engineering, Environmental E...     1_0
# 3  [General Chemical Engineering, Environmental E...     1_0
# 4  [General Chemical Engineering, Environmental E...     1_0

# %%
with open("q1_date_df", "rb") as fp:
    q1_date_df = pickle.load(fp)

# %%
q1_date_df.sample(10)
# Out:
#                                JRNL_ID                    ISSN  \
# DOI
# 10.3389/feart.2020.574206      1_65355             [2296-6463]
# 10.1111/arcm.12572               1_680  (0003-813X, 1475-4754)
# 10.1016/j.jsbmb.2015.01.009    1_20371             [0960-0760]
# 10.1080/14712598.2018.1544239  1_36613  [1471-2598, 1744-7682]
# 10.1115/1.4038879              1_17283  [0889-504X, 1528-8900]
# 10.1557/mrc.2014.14            1_63492  [2159-6859, 2159-6867]
# 10.1111/sapm.12220             1_34849  [0022-2526, 1467-9590]
# 10.1016/j.ejor.2010.04.017     1_15010             [0377-2217]
# 10.1109/tcsi.2010.2055250      1_44525  (1549-8328, 1558-0806)
# 10.1007/s13369-015-1920-6      1_64142  [1319-8025, 2191-4281]
#
#                                                          issued  \
# DOI
# 10.3389/feart.2020.574206        {'date-parts': [[2020, 9, 2]]}
# 10.1111/arcm.12572               {'date-parts': [[2020, 5, 8]]}
# 10.1016/j.jsbmb.2015.01.009         {'date-parts': [[2015, 4]]}
# 10.1080/14712598.2018.1544239  {'date-parts': [[2018, 11, 14]]}
# 10.1115/1.4038879                {'date-parts': [[2018, 4, 6]]}
# 10.1557/mrc.2014.14                 {'date-parts': [[2014, 6]]}
# 10.1111/sapm.12220              {'date-parts': [[2018, 6, 25]]}
# 10.1016/j.ejor.2010.04.017         {'date-parts': [[2010, 11]]}
# 10.1109/tcsi.2010.2055250           {'date-parts': [[2011, 1]]}
# 10.1007/s13369-015-1920-6      {'date-parts': [[2015, 10, 27]]}
#
#                                                                  container-title  \
# DOI
# 10.3389/feart.2020.574206                           [Frontiers in Earth Science]
# 10.1111/arcm.12572                                                [Archaeometry]
# 10.1016/j.jsbmb.2015.01.009    [The Journal of Steroid Biochemistry and Molec...
# 10.1080/14712598.2018.1544239             [Expert Opinion on Biological Therapy]
# 10.1115/1.4038879                                    [Journal of Turbomachinery]
# 10.1557/mrc.2014.14                                         [MRS Communications]
# 10.1111/sapm.12220                              [Studies in Applied Mathematics]
# 10.1016/j.ejor.2010.04.017            [European Journal of Operational Research]
# 10.1109/tcsi.2010.2055250      [IEEE Transactions on Circuits and Systems I: ...
# 10.1007/s13369-015-1920-6          [Arabian Journal for Science and Engineering]
#
#                                                                        publisher  \
# DOI
# 10.3389/feart.2020.574206                                     Frontiers Media SA
# 10.1111/arcm.12572                                                         Wiley
# 10.1016/j.jsbmb.2015.01.009                                          Elsevier BV
# 10.1080/14712598.2018.1544239                                 Informa UK Limited
# 10.1115/1.4038879                                             ASME International
# 10.1557/mrc.2014.14                      Springer Science and Business Media LLC
# 10.1111/sapm.12220                                                         Wiley
# 10.1016/j.ejor.2010.04.017                                           Elsevier BV
# 10.1109/tcsi.2010.2055250      Institute of Electrical and Electronics Engine...
# 10.1007/s13369-015-1920-6                Springer Science and Business Media LLC
#
#                                                                            title  \
# DOI
# 10.3389/feart.2020.574206      [Temperature Variation on the Central Tibetan ...
# 10.1111/arcm.12572             [Evaluation of Fe isotope values as a provenan...
# 10.1016/j.jsbmb.2015.01.009    [The effect of 1,25 dihydroxyvitamin D3 treatm...
# 10.1080/14712598.2018.1544239  [Respiratory syncytial virus vaccine: where ar...
# 10.1115/1.4038879              [The Effect of Real Gas Approximations on S-CO...
# 10.1557/mrc.2014.14            [Dielectric behavior related to TiOx phase cha...
# 10.1111/sapm.12220             [Rational Solutions of the Painlevé‐III Equation]
# 10.1016/j.ejor.2010.04.017     [Callable risky perpetual debt with protection...
# 10.1109/tcsi.2010.2055250      [Memory System Optimization for FPGA-Based Imp...
# 10.1007/s13369-015-1920-6      [Scour Formation Due to Laterally Inclined Cir...
#
#                                                                           author  \
# DOI
# 10.3389/feart.2020.574206      [{'given': 'Yue', 'family': 'He', 'sequence': ...
# 10.1111/arcm.12572             [{'ORCID': 'http://orcid.org/0000-0001-9095-85...
# 10.1016/j.jsbmb.2015.01.009    [{'given': 'Marsha', 'family': 'DeWitt', 'sequ...
# 10.1080/14712598.2018.1544239  [{'given': 'Asif', 'family': 'Noor', 'sequence...
# 10.1115/1.4038879              [{'given': 'Jekyoung', 'family': 'Lee', 'seque...
# 10.1557/mrc.2014.14            [{'given': 'Geunhee', 'family': 'Lee', 'sequen...
# 10.1111/sapm.12220             [{'ORCID': 'http://orcid.org/0000-0001-8300-74...
# 10.1016/j.ejor.2010.04.017     [{'given': 'Aksel', 'family': 'Mjøs', 'sequenc...
# 10.1109/tcsi.2010.2055250      [{'given': 'Xiaoheng', 'family': 'Chen', 'sequ...
# 10.1007/s13369-015-1920-6      [{'given': 'Mohammad', 'family': 'Vaghefi', 's...
#
#                                                                          subject  \
# DOI
# 10.3389/feart.2020.574206                 [General Earth and Planetary Sciences]
# 10.1111/arcm.12572                                        [Archaeology, History]
# 10.1016/j.jsbmb.2015.01.009    [Cell Biology, Clinical Biochemistry, Endocrin...
# 10.1080/14712598.2018.1544239  [Clinical Biochemistry, Drug Discovery, Pharma...
# 10.1115/1.4038879                                       [Mechanical Engineering]
# 10.1557/mrc.2014.14                                  [General Materials Science]
# 10.1111/sapm.12220                                         [Applied Mathematics]
# 10.1016/j.ejor.2010.04.017     [Information Systems and Management, Managemen...
# 10.1109/tcsi.2010.2055250                [Electrical and Electronic Engineering]
# 10.1007/s13369-015-1920-6                                    [Multidisciplinary]
#
#                                references-count  is-referenced-by-count  \
# DOI
# 10.3389/feart.2020.574206                   121                       3
# 10.1111/arcm.12572                           44                       3
# 10.1016/j.jsbmb.2015.01.009                  50                       4
# 10.1080/14712598.2018.1544239                70                      19
# 10.1115/1.4038879                            17                       6
# 10.1557/mrc.2014.14                          19                       4
# 10.1111/sapm.12220                           25                       3
# 10.1016/j.ejor.2010.04.017                   24                       4
# 10.1109/tcsi.2010.2055250                    32                      55
# 10.1007/s13369-015-1920-6                    11                      11
#
#                                                       published  \
# DOI
# 10.3389/feart.2020.574206        {'date-parts': [[2020, 9, 2]]}
# 10.1111/arcm.12572               {'date-parts': [[2020, 5, 8]]}
# 10.1016/j.jsbmb.2015.01.009         {'date-parts': [[2015, 4]]}
# 10.1080/14712598.2018.1544239  {'date-parts': [[2018, 11, 14]]}
# 10.1115/1.4038879                {'date-parts': [[2018, 4, 6]]}
# 10.1557/mrc.2014.14                 {'date-parts': [[2014, 6]]}
# 10.1111/sapm.12220              {'date-parts': [[2018, 6, 25]]}
# 10.1016/j.ejor.2010.04.017         {'date-parts': [[2010, 11]]}
# 10.1109/tcsi.2010.2055250           {'date-parts': [[2011, 1]]}
# 10.1007/s13369-015-1920-6      {'date-parts': [[2015, 10, 27]]}
#
#                                                published-print  \
# DOI
# 10.3389/feart.2020.574206                                  NaN
# 10.1111/arcm.12572                 {'date-parts': [[2020, 8]]}
# 10.1016/j.jsbmb.2015.01.009        {'date-parts': [[2015, 4]]}
# 10.1080/14712598.2018.1544239  {'date-parts': [[2018, 12, 2]]}
# 10.1115/1.4038879               {'date-parts': [[2018, 5, 1]]}
# 10.1557/mrc.2014.14                {'date-parts': [[2014, 6]]}
# 10.1111/sapm.12220                {'date-parts': [[2018, 11]]}
# 10.1016/j.ejor.2010.04.017        {'date-parts': [[2010, 11]]}
# 10.1109/tcsi.2010.2055250          {'date-parts': [[2011, 1]]}
# 10.1007/s13369-015-1920-6          {'date-parts': [[2016, 4]]}
#
#                                                published-online  \
# DOI
# 10.3389/feart.2020.574206        {'date-parts': [[2020, 9, 2]]}
# 10.1111/arcm.12572               {'date-parts': [[2020, 5, 8]]}
# 10.1016/j.jsbmb.2015.01.009                                 NaN
# 10.1080/14712598.2018.1544239  {'date-parts': [[2018, 11, 14]]}
# 10.1115/1.4038879                {'date-parts': [[2018, 4, 6]]}
# 10.1557/mrc.2014.14              {'date-parts': [[2014, 6, 1]]}
# 10.1111/sapm.12220              {'date-parts': [[2018, 6, 25]]}
# 10.1016/j.ejor.2010.04.017                                  NaN
# 10.1109/tcsi.2010.2055250                                   NaN
# 10.1007/s13369-015-1920-6      {'date-parts': [[2015, 10, 27]]}
#
#                                                                       direct_url  \
# DOI
# 10.3389/feart.2020.574206      https://sci.bban.top/pdf/10.3389/feart.2020.57...
# 10.1111/arcm.12572             https://sci.bban.top/pdf/10.1111/arcm.12572.pd...
# 10.1016/j.jsbmb.2015.01.009    https://sci.bban.top/pdf/10.1016/j.jsbmb.2015....
# 10.1080/14712598.2018.1544239  https://sci.bban.top/pdf/10.1080/14712598.2018...
# 10.1115/1.4038879              https://sci.bban.top/pdf/10.1115/1.4038879.pdf...
# 10.1557/mrc.2014.14            https://sci.bban.top/pdf/10.1557/mrc.2014.14.p...
# 10.1111/sapm.12220             https://sci.bban.top/pdf/10.1111/sapm.12220.pd...
# 10.1016/j.ejor.2010.04.017     https://sci.bban.top/pdf/10.1016/j.ejor.2010.0...
# 10.1109/tcsi.2010.2055250      https://sci.bban.top/pdf/10.1109/TCSI.2010.205...
# 10.1007/s13369-015-1920-6      https://sci.bban.top/pdf/10.1007/s13369-015-19...
#
#                                                            Dates  \
# DOI
# 10.3389/feart.2020.574206         [19 June 2020, 17 August 2020]
# 10.1111/arcm.12572              [21 October 2019, 20 April 2020]
# 10.1016/j.jsbmb.2015.01.009    [14 August 2014, 13 January 2015]
# 10.1080/14712598.2018.1544239   [19 April 2018, 31 October 2018]
# 10.1115/1.4038879                      [November 07, 2017, None]
# 10.1557/mrc.2014.14              [9 January 2014, 22 April 2014]
# 10.1111/sapm.12220                      [January 16, 2018, None]
# 10.1016/j.ejor.2010.04.017     [18 December 2008, 13 April 2010]
# 10.1109/tcsi.2010.2055250             [September 14, 2009, None]
# 10.1007/s13369-015-1920-6       [17 March 2015, 13 October 2015]
#
#                                                                         Keywords  \
# DOI
# 10.3389/feart.2020.574206      [(paleothermometry, 0.4758), (paleothermometer...
# 10.1111/arcm.12572             [(geology, 0.4036), (isotopes, 0.396), (archae...
# 10.1016/j.jsbmb.2015.01.009    [(dihydroxyvitamin, 0.3976), (hydroxyvitamin, ...
# 10.1080/14712598.2018.1544239  [(vaccines, 0.5156), (vaccine, 0.5111), (vacci...
# 10.1115/1.4038879              [(compressor, 0.3869), (turbine, 0.3517), (tur...
# 10.1557/mrc.2014.14            [(dielectric, 0.4435), (propertiesdielectric, ...
# 10.1111/sapm.12220             [(painlev, 0.3886), (painleve, 0.3712), (painl...
# 10.1016/j.ejor.2010.04.017     [(debtvalues, 0.4775), (debthold, 0.47), (debt...
# 10.1109/tcsi.2010.2055250      [(fpgas, 0.4843), (fpga, 0.4615), (fpgaemulati...
# 10.1007/s13369-015-1920-6      [(hydraulic, 0.3553), (pier, 0.3261), (scour, ...
#
#                                       Affiliation
# DOI
# 10.3389/feart.2020.574206                   China
# 10.1111/arcm.12572                  United States
# 10.1016/j.jsbmb.2015.01.009         United States
# 10.1080/14712598.2018.1544239       United States
# 10.1115/1.4038879              Korea, Republic of
# 10.1557/mrc.2014.14                 United States
# 10.1111/sapm.12220                  United States
# 10.1016/j.ejor.2010.04.017                 Norway
# 10.1109/tcsi.2010.2055250           United States
# 10.1007/s13369-015-1920-6                    Iran

# %% [markdown]
# Here, it is realized that the S_A column  for q1_date_df was created in (7a) but it was not saved.
#
# This isnot a huge loss, as we can assign the S_A after the fe SH_run & the entire dataset is collected. This can also allow a better assignment regard Currecnt_Count & Required_Count & CR_Count colunms.
#
# ---
#
# The next step is SH_run for fe dataset!

# %%
with open("q1_meta_fe","wb") as fp:
    pickle.dump(q1_meta_fe, fp)

# %%
q1_meta_fe.shape
# Out:
# (138184, 13)

# %%
# q1_meta_fe SH_Blastoise Ogi Run:

# from scihub_blastoise import SciHub_HydroPump
# import pickle

sh_h = SciHub_HydroPump()

# with open("q1_meta_fe", "rb") as fp:
#     q1_meta_fe = pickle.load(fp)

#q1_meta_fe_sum = q1_meta_fe[:45000]
#q1_meta_fe_cet = q1_meta_fe[45000:95000]
q1_meta_fe_ogi = q1_meta_fe[95000:]


doi_list = q1_meta_fe_ogi.DOI.tolist()

q1_date_fe_ogi = list() 


for doi in doi_list:
    pdf_url, date, kw = sh_h.get_dates_kws(doi)

    q1_date_fe_ogi.append(dict(DOI = doi, direct_url = pdf_url, Dates = date, Keywords = kw))


with open("q1_date_fe_ogi","wb") as fp:
    pickle.dump(q1_date_fe_ogi, fp)

# %%
# Test Run:

doi_list = q1_meta_fe.sample(5).DOI.tolist()

q1_date_fe_ogi = list() 


for doi in doi_list:
    pdf_url, date, kw = sh_h.get_dates_kws(doi)

    q1_date_fe_ogi.append(dict(DOI = doi, direct_url = pdf_url, Dates = date, Keywords = kw))

# %%
pd.DataFrame(q1_date_fe_ogi)
# Out:
#                                 DOI  \
# 0     10.1088/0268-1242/30/8/084001
# 1         10.1017/s0954579419000130
# 2          10.1177/1074248413504994
# 3         10.1016/j.whi.2012.10.001
# 4  10.1111/j.1755-263x.2010.00162.x
#
#                                           direct_url  \
# 0  https://sci.bban.top/pdf/10.1088/0268-1242%252...
# 1  https://sci.bban.top/pdf/10.1017/s095457941900...
# 2  https://sci.bban.top/pdf/10.1177/1074248413504...
# 3  https://sci.bban.top/pdf/10.1016/j.whi.2012.10...
# 4  https://sci.bban.top/pdf/10.1111/j.1755-263x.2...
#
#                                 Dates  \
# 0                 [31 May 2015, None]
# 1                       no_date_found
# 2     [May 28, 2013, August 15, 2013]
# 3       [8 June 2012, 9 October 2012]
# 4  [7 October 2010, 16 December 2010]
#
#                                             Keywords
# 0  [(igbts, 0.3377), (mosfets, 0.3217), (igbt, 0....
# 1  [(psychoneuroendocrinology, 0.4846), (stressor...
# 2  [(atherosclerosis, 0.5629), (atherothrombosis,...
# 3  [(contraception, 0.6124), (contraceptive, 0.56...
# 4  [(wildlife, 0.6136), (tiger, 0.5459), (tigers,...

# %% [markdown]
# Test run is completed! SumCetCet run can be initiated!
#
# As the whole loop might take a while, will start the loop in chunks below:
#
# __NOTE: DON'T FORGET TO KEEP q1_date_fe_ogi & DO NOT RE-CREATE!__

# %%
# q1_meta_fe SH_Blastoise Ogi Run: - PART 1

# from scihub_blastoise import SciHub_HydroPump
# import pickle

sh_h = SciHub_HydroPump()

# with open("q1_meta_fe", "rb") as fp:
#     q1_meta_fe = pickle.load(fp)

#q1_meta_fe_sum = q1_meta_fe[:45000]
#q1_meta_fe_cet = q1_meta_fe[45000:95000]
q1_meta_fe_ogi = q1_meta_fe[95000:105000]


doi_list = q1_meta_fe_ogi.DOI.tolist()

q1_date_fe_ogi = list() 


for doi in doi_list:
    pdf_url, date, kw = sh_h.get_dates_kws(doi)

    q1_date_fe_ogi.append(dict(DOI = doi, direct_url = pdf_url, Dates = date, Keywords = kw))


with open("q1_date_fe_ogi_part1_7c","wb") as fp:
    pickle.dump(q1_date_fe_ogi, fp)
# Out:
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d64c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dacb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dc54 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1de1a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1df7b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e119 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e3cf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e680 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e921 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eaba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1afe0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b166 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b3e7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b59d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b763 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b8e9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bb12 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bd60 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bee6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c11f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c300 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x206a1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x209c4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20b9d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20d23 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20e8c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21085 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2123b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21494 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21735 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21906 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b853 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bb52 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bd88 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bf3e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c0dc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c262 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c468 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c669 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c8da for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ca6b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29a61 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29dbd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a036 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a20f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a3e5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a5c6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a7b4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a94a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ab90 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2aee9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b0ca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b313 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b4f4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fedb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3023b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30501 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x307ca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30a20 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30c99 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30ea7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x310dd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x312d3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3171c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x319ad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31c3e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31ed7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32148 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32301 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15a7e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15cb9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15e47 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16030 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x161fe for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1645f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x166a0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10060 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x101da for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10360 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10576 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x106ff for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b5e0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b791 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b93f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bb25 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bd33 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bfac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c105 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c286 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x49d38 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x49fc1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4a29f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4a4f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4a741 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4a99f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4ac68 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4af71 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4b23a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4b58b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4b87c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4baa5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4bc16 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4bd6f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4bec8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4c021 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4c17a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4c2fb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31a22 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31dd9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x320f3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32475 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3288f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32be9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32fab for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3326d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x333cf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33531 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33693 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3381d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x279bf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27c19 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27e33 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28042 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28251 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28428 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28607 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x288b6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28a65 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28ce4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28ec6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29028 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x291b2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a206 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a56b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a735 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a8e4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2aab3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ac8d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ae27 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2afc6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b17d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b30c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b55b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b6dd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b93f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bb61 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22422 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x226c7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2289d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22acb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22c51 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22e12 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2304b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x231d1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x233cf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x235cd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23776 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23987 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a6d3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a83c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a9ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1aba3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ad31 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1af07 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b0c0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b249 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32a76 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32c17 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32d90 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32f39 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x330cf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x332a0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33426 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3367f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33805 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33a06 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33b8c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33ded for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33f93 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34199 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x342fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3447b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x338ad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33be7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33ffd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34336 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3453c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34a15 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34e8e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3504c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35445 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x356e3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35acc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35d65 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36016 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x362c7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36520 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x992d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9b7b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20ea7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2128a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21410 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x216a9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x219b2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21dbb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21ff4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2226d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x224de for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb629 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb822 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36e6a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x372d5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37436 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37627 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37929 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37bc3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37d55 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37eef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38071 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x381e3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38355 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x384c7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38740 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38f81 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3957a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x397bb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39a3c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39ccd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39f83 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a122 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f96f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2faf5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fd4e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fed4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x300d2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x302c0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x304be for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x306d4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3092a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30b43 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30d0c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30edd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3108e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3131f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31598 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36150 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3649d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3661e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x367af for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36a38 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36baa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36e44 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36fe6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37190 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3736a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37623 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37954 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37b65 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37d67 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37fe8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38219 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1df2a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e111 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e3a8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e64f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e9d6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eb38 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ec9a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ee24 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x92fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26c8a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2709f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27238 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27409 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x275e7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27795 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27933 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27ad9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27d3f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27f95 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28156 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x283e7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x285c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ddd2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2dfa8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e151 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e332 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e508 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e67a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e800 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e9e6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2eccf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2eef5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f07b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f1d4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f32d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f496 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f617 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f770 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f8f1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xcc3a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xce09 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xd0ba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xd253 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x107ad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10ac4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10d0a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10f23 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x110c4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cf97 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d1fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d3a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d529 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d6fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d890 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2da61 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2dc22 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ddc0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e086 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e267 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e528 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e6f1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e98a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x54c2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34409 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34593 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34707 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34880 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x349d9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34b5f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34eb8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35029 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35182 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x353a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3552c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35695 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35806 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35a9f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35c58 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38cf9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38eba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39013 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3918c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3933d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x394cb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39681 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39807 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x399c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39b6e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39d84 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39f82 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a138 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a3c1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a547 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a820 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a979 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3aafa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f420 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f6a7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f83d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f9c6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fb5c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fcfa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fee8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20139 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2039f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2056d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20806 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3789b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37c40 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37f79 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38212 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3851b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x387ac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38b15 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38d76 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38f8f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x391f5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3945e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x396cf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39950 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39bd1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39e1a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22831 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22aca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22cb8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22e5e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22fb7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23168 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x232c1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2346f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23685 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2389b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23aa9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23c9a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23f3b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3f775 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3fa42 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3fc9b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3fe81 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40112 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40373 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4061c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4090d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40c9e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40ec8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x411c9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41482 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41703 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4194c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41bf5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41e86 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42117 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42378 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4baa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9e16 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ff2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xa194 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20f42 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x211ab for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x213e4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x215f5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21803 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x219e5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21b97 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21d29 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21ec3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2201c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x221a6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2232c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x225ad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x227e6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x196ec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1996d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19ac6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19d1c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19f12 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a0f3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a299 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a482 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a66b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c9ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cc2e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cdd7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cfe8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d16e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d324 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d4aa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d650 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d979 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2dbe2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2dfbb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e1bc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e41d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e676 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23196 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23390 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23579 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23703 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2385c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23a2e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23bc0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23d59 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2403a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x242b3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2440c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2458d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b523 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b814 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b99a for key /MediaBox [generic.py:587]
# ...
# PdfReadWarning: Multiple definitions in dictionary at byte 0x8e47 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9017 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a41f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a82a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a9f3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2abdc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2adf2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2afe0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b16e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b354 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b572 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b97b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bb69 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bd9a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c013 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c254 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23a30 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23ce8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23e79 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24097 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24290 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24439 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24627 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x247ad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24a93 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24cf4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24f55 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5bb1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x252b8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25709 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x258e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25af3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25c79 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25dff for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2601d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x261ab for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26434 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2670d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2699e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26c1f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x91d9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9419 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb42b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb65c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb826 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31d4d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3203c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3233e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3250d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x326c4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3289e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32aad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32c7f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32e26 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32ffd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3316c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3330e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3349d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x336b7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33871 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33b13 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33d65 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eb8b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed9d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ef1f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f0e9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f318 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f5aa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f734 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f8be for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19e0a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a034 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a1af for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a3e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a55d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a740 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a9a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ab5e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ace8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ae72 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28a89 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28cda for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28e88 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2901e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x291ac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2934d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2959b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29834 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29a5d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29cee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29f07 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a026 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a3e5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a5a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a76c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a962 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ab40 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ad31 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2aecf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b1b0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b342 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b520 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b721 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b992 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bbeb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26043 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2641c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26685 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26876 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26a2c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26bcd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26d53 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26f84 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2726d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x274ae for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2774f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x278d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31ecc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x324ff for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32838 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32ad9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32c5f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32e80 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3301e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33224 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3352a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x336f0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33979 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33bea for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33e7b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34114 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x342ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xaaf5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xace8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xae89 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb3d3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb5c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb789 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x629b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x63ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x384c5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x386cb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x388d9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38b72 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38d83 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38f04 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3910d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x392c3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39469 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x396aa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x398d8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39aa6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39c37 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39dc5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39fa6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a0ff for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a280 for key /MediaBox [generic.py:587]

# %%
# q1_meta_fe SH_Blastoise Ogi Run: - PART 2

# from scihub_blastoise import SciHub_HydroPump
# import pickle

sh_h = SciHub_HydroPump()

# with open("q1_meta_fe", "rb") as fp:
#     q1_meta_fe = pickle.load(fp)

#q1_meta_fe_sum = q1_meta_fe[:45000]
#q1_meta_fe_cet = q1_meta_fe[45000:95000]
q1_meta_fe_ogi = q1_meta_fe[105000:120000]


doi_list = q1_meta_fe_ogi.DOI.tolist()

#q1_date_fe_ogi = list() 


for doi in doi_list:
    pdf_url, date, kw = sh_h.get_dates_kws(doi)

    q1_date_fe_ogi.append(dict(DOI = doi, direct_url = pdf_url, Dates = date, Keywords = kw))


with open("q1_date_fe_ogi_part2_7c","wb") as fp:
    pickle.dump(q1_date_fe_ogi, fp)
# Out:
# PdfReadWarning: Multiple definitions in dictionary at byte 0x73d0f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x7405c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x74216 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x74530 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x746f2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x748a4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x74a7e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x74c38 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x74e22 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x75044 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x751f6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x754a0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb549 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb762 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb93c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d5508 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d5692 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d587c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d59e6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d5b8d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d5d30 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d5efa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d6074 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d626e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d63d8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d655e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d6780 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d690a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x5d6a6c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb041 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xb1cb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x247a6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2498d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24bae for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24da7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24f80 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25109 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2529f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x254bd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25653 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x257fc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25a55 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25bee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf493 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf661 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf8a2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xfa28 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x194df for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19746 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1993f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19b1d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19cbb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19e61 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19fff for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a1c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a3e1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x39fcb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a201 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a48a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a693 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3a8a4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3aab5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3ac4e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3ae37 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3b03d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3b233 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3b3ec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3b5ea for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3b770 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3b959 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3bb12 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3bda3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3bf9c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b2fd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b732 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b95b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bafc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bcf5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bf13 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c109 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c2d7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c46d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c5f3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c7f9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ca0a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cb8b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ce14 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d03d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1beea for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c1c6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c43f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c5e5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c7ce for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c96c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cadd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ccfe for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x43a37 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x43f2d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x441ae for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4432f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x444c9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x446a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x44815 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4499f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x44b79 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x44d62 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x44ef0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x450da for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x45404 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x45685 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x458ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x45b6f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x120e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1243e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x12600 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x127ba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x129eb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x12b74 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3f3cc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3f8aa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3fab0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3fc76 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3fe24 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3ffd2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4017b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40321 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x404ff for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x406ad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4085b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40ab4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40c6a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x40ec0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x410ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x412fc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x414fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41778 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x419f1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41c7a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41ecb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x63c68 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x63dd9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x640ca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64258 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x643b1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6459a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x646fb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x648d1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64a5a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64c3b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64e4c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65002 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x651d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x653a6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65557 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65760 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65931 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65aa2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65c4b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65de1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65f97 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66195 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66363 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x664f4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6667a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6680b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6699c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66b22 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66c83 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66eac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x670f5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6724e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x67407 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x67698 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x678c9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c684 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c8b9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ca62 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cd43 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cfc1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d167 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d38d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d563 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d779 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d9c7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2dbad for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ddd6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e027 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e248 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e441 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ea3d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed8c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1efc2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f1a8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f37e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f564 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f752 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f988 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fbf6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fde4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ff6a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x200f0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x202b6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x204f7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x206b0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66837 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x669bd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66b3d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e14f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e310 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e4e6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e66c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e805 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e9c3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ecac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ee05 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ef86 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xa042 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xa1cc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xa341 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed65 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f036 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f1f5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f56f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f766 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fa80 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fdfa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x200ac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x202b6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32f8d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x332ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33474 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3364d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33866 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33a1f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33ca8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33ece for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x340bc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3429a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34450 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x346c1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x349f2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34c3b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x34ec4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x35085 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x63efb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x641d4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64605 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64a9e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x64d57 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65058 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65261 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6546a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65663 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x659cc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x65e35 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x662be for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66524 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66885 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66aee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x66d5c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x67099 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6751a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x678f0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x67b9d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x67e5c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x68112 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x683d1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x68687 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x68910 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x68ba2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x68e46 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x69075 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2455c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x247f4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24a02 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24deb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24fc4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x251a2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2532b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x254d4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x257f5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25bf6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25e6f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26008 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41126 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x41b6f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42018 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42231 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x423a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4251d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42817 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42a31 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42c53 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42e6d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x42fe7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x431f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4337a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x434fc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x43736 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x439b8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x43c6e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x43f24 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4419b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x4441b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x446c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x44894 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29071 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29318 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29491 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29662 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2980c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x299b6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29b78 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29d2a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29ed4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a156 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a358 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a55a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a75c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a97d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2abce for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25b13 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25e29 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26067 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2629d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2652e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26754 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x268e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26aa8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26d39 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26eef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x270e8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27371 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x275e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24fc0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25272 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25483 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2575c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x259a5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25cce for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25f97 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26178 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x263e1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26642 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed09 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f00e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f207 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f3c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f56a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f6fb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f854 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f9e6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fb3f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1fd10 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ff59 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xe770 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xe904 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xead5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x6f14 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19f71 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a234 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a3cd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a5ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a808 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a9f9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ac22 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bfac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c3d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c5a1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c722 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c98b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cb64 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cddd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cfbe for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ad07 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b03c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b29d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b4bf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b658 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b82a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b9ec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bc5d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25cdb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2605c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26395 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x266bb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26901 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26a8f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26c55 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26e9e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x270d7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x272e0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x274f1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10a29 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10c78 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x10e3a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x11043 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1121c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d6e0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d8ca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1da61 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dc50 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ddf7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e026 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e240 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e3ca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26c7f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26e31 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26ffb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27192 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2731c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27573 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27745 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2790c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27acb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27c8a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27e1c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27f7e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f6d7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f970 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fba1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fd52 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ff13 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x300b9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30242 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x303e8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30561 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30707 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30878 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30a06 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30bcf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30da8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30f41 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15d71 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15f70 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16117 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x162c6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16495 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1661f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x121d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x124cb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x12744 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x12915 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x12b46 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x163ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x167fd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x169a6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16b8c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16e45 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1706e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1624d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1654e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x167ef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16948 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16ac9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x308a3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30adc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30c6a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30e0b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30fac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3112d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31296 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31408 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31619 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31772 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x318db for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31a81 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31c33 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31e09 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31f6a for key /MediaBox [generic.py:587]
# ...
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21bbc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21d2e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21ee5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22074 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x222c6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22465 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22644 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x227fb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22a05 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22c97 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22eb1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2180d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21a1a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21b7b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21d74 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21f0a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x220c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22276 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22474 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x226a2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x228b3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22a8c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17bc9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17d89 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17efa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18090 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x181f9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1837f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18530 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18779 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x292a9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29575 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29704 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2999e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29b2d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29cec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29f76 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a105 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a294 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a4d6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a668 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a7ea for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2aa44 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ace6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2aea8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2841d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28649 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x287ab for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28a3d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28cd4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28f26 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x291f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x293ca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2964c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x298de for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29b88 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29d42 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21242 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2145c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2169a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21873 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21a54 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21c4d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21e46 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x220bf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22340 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dfdc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e2c8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e529 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e737 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e965 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eb03 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed2c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1efb5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f1b6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32082 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32206 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3247b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x326ec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32872 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32abb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32cec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32ed5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x330fe for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3336f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33588 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33801 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33aba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33d4b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3217e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32396 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x325fc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3285d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32ad6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32d87 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x32fed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33206 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33467 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x336d8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33959 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33bca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x33e13 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e2bc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e4d5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e686 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e81c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e9d2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eb90 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed56 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eeec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f07a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f233 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f444 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15a85 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15e16 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x15fef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16148 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x162c9 for key /MediaBox [generic.py:587]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FDAB68E770> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD98138E50> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9AA8A9A0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD982984A0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD979BA770> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD986BE590> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9AC3B450> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FDA67D7770> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9675C3B0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD97CD24A0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9C0CDD10> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9658FF40> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9C4F40E0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9AE10090> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9675CC70> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9AF5E220> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9674DB30> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9AC40400> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]

# %%
# q1_meta_fe SH_Blastoise Ogi Run: - PART 3

# from scihub_blastoise import SciHub_HydroPump
# import pickle

sh_h = SciHub_HydroPump()

# with open("q1_meta_fe", "rb") as fp:
#     q1_meta_fe = pickle.load(fp)

#q1_meta_fe_sum = q1_meta_fe[:45000]
#q1_meta_fe_cet = q1_meta_fe[45000:95000]
q1_meta_fe_ogi = q1_meta_fe[120000:]


doi_list = q1_meta_fe_ogi.DOI.tolist()

#q1_date_fe_ogi = list() 


for doi in doi_list:
    pdf_url, date, kw = sh_h.get_dates_kws(doi)

    q1_date_fe_ogi.append(dict(DOI = doi, direct_url = pdf_url, Dates = date, Keywords = kw))


with open("q1_date_fe_ogi","wb") as fp:
    pickle.dump(q1_date_fe_ogi, fp)
# Out:
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9C212590> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9651E360> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD996A8CC0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FDAB272E50> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9DEF8D10> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FDAB2E42C0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9CD62EA0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FDAB21AAE0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD9E436540> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FDAB5479A0> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PDFTextExtractionNotAllowedWarning: The PDF <_io.BytesIO object at 0x000001FD8F2CCF40> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. [pdfpage.py:159]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a891 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a89e for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8ab for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8b8 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8c5 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8d2 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8df for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8ec for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a8f9 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a906 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a913 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a920 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a92d for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a93a for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9a947 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa24 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa31 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa3e for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa4b for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa58 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa65 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa72 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa7f for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa8c for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aa99 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aaa6 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aab3 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aac0 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aacd for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aada for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aae7 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9aaf4 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab01 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab0e for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab1b for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab28 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab35 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab42 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab4f for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab5c for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab69 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab83 for key /Im65 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ab9d for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9abaa for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9abb7 for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9abc4 for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9abd1 for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9abde for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ba60 for key /Im317 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9ba6d for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bba6 for key /Im66 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bca3 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bcb0 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bcbd for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bcca for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bcd7 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bce4 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bcf1 for key /Im48 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd0f for key /Im354 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd1e for key /Im354 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd2d for key /Im354 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd3c for key /Im354 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd4b for key /Im354 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd5a for key /Im354 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd78 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd87 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bd96 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bda5 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bdb4 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bdc3 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bdd2 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bde1 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bdf0 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bdff for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be0e for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be1d for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be2c for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be3b for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be4a for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be59 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be68 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9be77 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9beb3 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bec2 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bed1 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9bee0 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9beef for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9c246 for key /Im360 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc0f for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc1e for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc2d for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc3c for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc4b for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc5a for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc69 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc78 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cc87 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cd86 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cd95 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cda4 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cdb3 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cdc2 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cdd1 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cde0 for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cdef for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cdfe for key /Im358 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cfed for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9cffc for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d00b for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d01a for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d029 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d038 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d047 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d056 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d065 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d074 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d083 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d092 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d0a1 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1a0 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1af for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1be for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1cd for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1dc for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1eb for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d1fa for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d209 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d218 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d227 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d236 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d245 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d254 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d263 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d272 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d3cb for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d3da for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d3e9 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d3f8 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d407 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d416 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x9d425 for key /Im355 [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20f6b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x212ae for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2143c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x215fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21858 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21a0e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21d07 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21e60 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21fb9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22232 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2241b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16661 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x167da for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16963 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16b39 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16d32 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16ed3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25c99 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25f6c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26125 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x262ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x264ef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26691 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26803 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x269c5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26c7e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26e4f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x270c0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27289 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23bec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23ec5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x240be for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x242af for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24435 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2465b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24809 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24a2f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24ced for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24f0e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25197 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25348 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2eb05 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ed18 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ef29 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f10a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f2ac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f41e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f697 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f8b9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fadb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fc4d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30036 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30317 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30538 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x307d1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x309e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b3b2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b663 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1b8a4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ba36 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bba8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bd8a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c00c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c225 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c41e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20c26 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20fd2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21223 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x213b5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2153f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21719 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21903 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21ae4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21d65 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21f96 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d155 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d3b3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d56a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d804 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1da03 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dbd2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dd91 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1df93 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e1b5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e191 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e3fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e594 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e763 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e932 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eac1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ecc0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eebf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f116 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f368 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f50a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f12b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f4d5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f69c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f866 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fa50 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fc0a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2fe49 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30108 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3036f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30731 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30a03 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30c05 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x30e87 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x31089 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b38d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b6fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b9b1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bb70 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2be4a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c1ac for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c3ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c605 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c8ef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ca79 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cd03 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cfa5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2d17f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c632 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c960 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cb16 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cc9c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ceca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d090 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d2c9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d442 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d64b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d804 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x273d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x277a9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2796b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27c05 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27d94 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2803e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x281ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2837c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28563 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28855 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28a77 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28ce9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28f2b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c452 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c648 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c949 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cc12 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cd6b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cec4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d045 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x13085 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x13293 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x13419 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x135f2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x137c3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24111 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x242da for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24480 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2463e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x247f4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x249c2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24b78 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24d06 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24f5c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x250e2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x252d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x254c1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x256ea for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18a47 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18c80 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18ec6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1915f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x192e5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1944e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x195cf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2656c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x266d5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x268db for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26a91 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26c37 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26e4d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27013 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27201 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2740f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x275c5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2778e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x278e7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27a68 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x958d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b5f9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b782 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b90b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bac1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bc6f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2be4d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2bfe3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c174 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c2f6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c50c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c665 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2c7be for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ca77 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cc60 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2cde1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18e91 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1902f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19235 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1942b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19681 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x19802 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24278 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x244a6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24787 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24a98 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24c46 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24dc7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2500d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25266 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x253c7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25568 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2457e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24707 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x248d8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24ace for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24d14 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24eba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25070 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25236 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2542c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x255ba for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25843 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x259ec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a321 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a4a2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a640 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a859 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1a9df for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1abc5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ad53 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1aed4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17cab for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17ff4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18282 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x183db for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1855c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22516 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22737 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2293d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22af3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22cc9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x22eaf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x230f5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2335e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x234b7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23638 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x245b5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2493f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24c91 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24fab for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25355 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25737 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x258d9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25a3b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25b9d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25d27 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1dd29 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1df3b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e14d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e30c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e4f3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e692 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e8cc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ea56 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x472ed for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x47596 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x47827 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x47a90 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x47cd9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x47f52 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x48142 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x483cb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x48584 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x486dd for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x48836 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x489b7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x252f9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2547f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x257f9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x259a8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25d32 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2605c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2639e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x265f0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26882 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26b0c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26cc6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25d8b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x260d2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26301 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2664b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x267da for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26b9c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26eb6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x270f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27392 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2763c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x277ee for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1d1e3 for key /MediaBox [generic.py:587]
# ...
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2868f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28825 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x289f3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28b9c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28e15 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28fb6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1be7e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c092 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c225 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c428 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c5bf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c759 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c910 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cae2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cd54 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1cefe for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29b49 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29d54 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x29ee6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a088 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a21f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a3c6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a530 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a6df for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2a8e9 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2aa90 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ac62 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ae04 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b076 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2b2d0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e604 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e837 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e9b8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eb66 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed17 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ee90 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f019 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f182 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f3fb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ded6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e13f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e301 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e4d8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e68f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1e84e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1eb55 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ed5f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1f001 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x36fd5 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3721e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37447 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x375e0 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37739 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x378bf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37a18 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37b71 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37cca for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37e43 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x37f9c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x3810d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38326 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38507 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x386f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38989 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x38b82 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1798a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17b96 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17e34 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17fea for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18188 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18326 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x184b4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18702 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x188e3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x18afc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x16e36 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x171ef for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17425 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1769e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17877 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17a15 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17c66 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x17df7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ba49 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1bc8a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1be69 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c018 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c1bf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c36e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c520 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c6c7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1c869 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x1ca3b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20cdf for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x20fa3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2119a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2134c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2150e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21780 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2195a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21bd4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x21e06 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27688 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2787c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27a23 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27b9d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27d97 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27f7e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28100 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x282b7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28486 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28670 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2880a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28a84 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x28c0e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf41c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf5f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf7fa for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xf9bc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0xfb66 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24360 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x246ec for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x248b6 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24a75 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24c2c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x24e03 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2502d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x251b7 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25431 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x256b3 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x25865 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x263af for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x265f8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2676a for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x268e4 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26a56 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26bf8 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26da2 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x26f2c for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x270bb for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2726d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27457 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x27699 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2dfa1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e188 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e346 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e51f for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e708 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2e8c1 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ea92 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ec4b for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2edcc for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2ef4d for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f19e for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f407 for key /MediaBox [generic.py:587]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2f5e0 for key /MediaBox [generic.py:587]

# %% [markdown]
# ## Part 3: After SciHub Run:

# %% [markdown]
# SumCetCet for Q1_fe is completed! The nb will be reset and results will be analyzed.
#
# Depending on the extracted information, will re-calculate Required_Count & update nb info accodringly!

# %%
with open("q1_date_fe_sum", "rb") as fp:
    q1_date_fe_sum = pickle.load(fp)

with open("q1_date_fe_cet", "rb") as fp:
    q1_date_fe_cet = pickle.load(fp)

with open("q1_date_fe_ogi", "rb") as fp:
    q1_date_fe_ogi = pickle.load(fp)

# %%
q1_date_fe_sum = pd.DataFrame(q1_date_fe_sum)
q1_date_fe_cet = pd.DataFrame(q1_date_fe_cet)
q1_date_fe_ogi = pd.DataFrame(q1_date_fe_ogi)

q1_date_fe = pd.concat([q1_date_fe_sum,q1_date_fe_cet,q1_date_fe_ogi], ignore_index=True)

# %%
q1_date_fe.Dates.map(type).value_counts()
# Out:
# <class 'list'>    108345
# <class 'str'>      29839
# Name: Dates, dtype: int64

# %%
q1_date_fe[q1_date_fe.Dates.map(type)==str].Dates.value_counts()
# Out:
# no_date_found            26748
# article_not_in_Scihub     2951
# cant_read_pdf              137
# direct_url_error             2
# pdf_bytes_error              1
# Name: Dates, dtype: int64

# %% [markdown]
# It is seen that the majority of the errors are caused by "NO DATE". However, to clearly understand this issue, we need JRNL_ID column as well.

# %%
with open("q1_meta_fe", "rb") as fp:
    q1_meta_fe = pickle.load(fp)

q1_date_fe = q1_date_fe.merge(q1_meta_fe[["DOI","JRNL_ID"]], how="left", left_on="DOI", right_on="DOI")

# %%
q1_anlys = q1_date_fe.groupby("JRNL_ID").Dates.apply(list)
q1_anlys = pd.DataFrame(q1_anlys)

q1_anlys["list_total"] = q1_anlys.Dates.map(len)
q1_anlys["list_succ"] = q1_date_fe.groupby("JRNL_ID").Dates.apply(list).map(lambda x: len([i for i in x if type(i)==list]))
q1_anlys["list_diff"] = q1_anlys["list_total"] - q1_anlys["list_succ"]

# %%
# PARTIAL OK:

len(q1_anlys[q1_anlys.list_diff > 0].sort_values("list_diff",ascending=False))
# Out:
# 11054

# %%
#FULL OK:
len(q1_anlys[q1_anlys.list_diff == 0])
# Out:
# 14012

# %%
# ZERO OK:
len(len(q1_anlys[q1_anlys.list_succ == 0].sort_values("list_total", ascending=False)))
# Out:
# 1976

# %% [markdown]
# There are 3 types of jrnls:
#
# - _FULL OK_ : These journals have completely satistfied the Required_count conditions. These jrnls might be used to instead of failed retr.
#
# - _PARTIAL OK_ : These journals have DATE INFO only for SOME jrnls. These jrnls should be subjected to a custom loop to get maximum artcls
#
# - _ZERO OK_ : These jrnls did not have any DATE INFO from extracted artcls although they were marked as SH_Results == True
#
# To get a better understanding of the situation & calc & create new loops, we need q1_jrnl_df imported

# %%
with open("q1_jrnl_df", "rb") as fp:
    q1_jrnl_df = pickle.load(fp)

with open("q1_jrnl_expladed", "rb") as fp:
    q1_jrnl_expladed = pickle.load(fp)

# %%
q1_jrnl_df = q1_jrnl_df.merge(q1_anlys[["list_total","list_succ","list_diff"]], how="left", right_index=True, left_index=True)

# %%
# NOT in CrossRef:
print(f"Number of not included in CR journals: {len(q1_jrnl_df[(q1_jrnl_df.list_total.isna()) & (q1_jrnl_df.Required_Count > 0)])}")


print(f'Number of artcls from these journals: {q1_jrnl_df[(q1_jrnl_df.list_total.isna()) & (q1_jrnl_df.Required_Count > 0)]["Required_Count"].sum()}')
# Out:
# Number of not included in CR journals: 9
# Number of artcls from these journals: 78

# %%
# CR_Count changed jrnls:

len(q1_jrnl_df[(q1_jrnl_df.Required_Count > q1_jrnl_df.list_total)])
# Out:
# 1

# %%
my_etiquette = Etiquette('Analysing Publishing Delay in Academic Journals', 'v2.0', 'https://github.com/Spidey0023/THEsis-Codes', 'oguzkokes@gmail.com')
ogi_works = Works(etiquette=my_etiquette)


ogi_works.filter(issn=["10870571", "1552454X"], from_pub_date=2016, until_pub_date=2016, type="journal-article").count()
# Out:
# 1

# %% [markdown]
# __The analysis so far shows that:__
#
# We have 2 areas to focus:
#
# ___JRNL related issues: (CrossRef)___
#
# - 9 jrnls were removed from CrossRef entirely!
#
# - 1 jrnl, 1_24843, had CR_Count 78, but now only 1
#
#
# ___ARTCL related issues: (NO DATE & not in SH)___
#
# - 1976 jrnls were marked as SH_Results = True, but had 0 successful retrial => complete failure - ZERO_OK
#
# - 11054 jrnls PARTIAL_OK
#
# - rest worked completely as expected!
#
#
# ---
#
# ___TTD___:
#
# 1- create new version of q1_date_df,
#
# - save q1_date_fe
# - save q1_meta_fe
# - filter & inner join together
# - modify & feat. eng
# - merge with q1_date_df to create new version!
#
# 2- q1_jrnl_df update:
#
# - 9+1 CR_Count,
#
# - 1976 SH_Results
#
# 3- def partial func
#
# 4- re-check q1_jrnl_df for CR_Count & SH_Results?

# %% [markdown]
# #### 1 - q1_date_df updates:

# %%
#1 q1_date_fe & q1_date_df merging:

# 1.1 - save q1_date_fe:
q1_date_fe_all = q1_date_fe.copy()

with open("q1_date_fe_all","wb") as fp:
   pickle.dump(q1_date_fe_all, fp)

# Saved in 7c SH run folder!

# Also duplicated q1_meta_fe_all & SAVED in same folder!

# %%
# 1.2 - Merging the two:
q1_date_fe = q1_meta_fe.merge(q1_date_fe.drop("JRNL_ID", axis=1), how="inner", left_on="DOI", right_on="DOI")

# 1.3 - Filtering to only successful artcls:
q1_date_fe = q1_date_fe[q1_date_fe.Dates.map(type)==list]
q1_date_fe.set_index("DOI", drop=True, inplace=True)

# %%
# 1.4 - Feature Eng. : 
def earlier_date_part(row):
    try:
        pp_year = row["published-print"]["date-parts"][0][0]
    except TypeError:
        pp_year = None

    try:   
        po_year = row["published-online"]["date-parts"][0][0]
    except TypeError:
        po_year = None

    if po_year is None:
        return row["published-print"]

    elif pp_year is None:
        return row["published-online"]

    else:
        if pp_year<po_year:
            return row["published-print"]
        elif po_year<pp_year:
            return row["published-online"]
        else:
            try:
                pp_month = row["published-print"]["date-parts"][0][1]
            except IndexError:
                pp_month = 12
            try:
                po_month = row["published-online"]["date-parts"][0][1]
            except IndexError:
                po_month = 12
            if pp_month<po_month:
                return row["published-print"]
            elif po_month<pp_month:
                return row["published-online"]
            else:
                return row["published-online"]


q1_date_fe.loc[:,"published"] = q1_date_fe.apply(earlier_date_part, axis=1)

q1_date_fe = q1_date_fe[["JRNL_ID", "ISSN", "issued", "container-title", "publisher", "title", "author", "subject", "references-count", "is-referenced-by-count", "published", "published-print", "published-online", "direct_url", "Dates", "Keywords"]]

# %%
# 1.5 - Merge:

with open("q1_date_df", "rb") as fp:
    q1_date_df = pickle.load(fp)

# %% [markdown]
# It is seen that 1671 articles are duplicated btw q1_date_df & q1_jrnl_fe. When analyzed, the two have different values on "Dates" and "Keywords" columns (as expected). As the newer results are to be more precise & old 1671 will be dropped from q1_date_df
#
# __Before the merge, q1_date_df is SAVED as q1_date_df_old in 7c SH folder!!!__

# %%
shared_dois = list(set(q1_date_df.index).intersection(set(q1_date_fe.index)))

# %%
# Proof that 2 dfs have different "Dates" for duplicate DOIs:
q1_date_df.loc[shared_dois,"Dates"].equals(q1_date_fe.loc[shared_dois,"Dates"])
# Out:
# False

# %%
q1_date_df = pd.concat([q1_date_df.drop(shared_dois), q1_date_fe], verify_integrity=True)

# %%
# 1.6 - Saving & DUMPing the updated q1_date_df:

with open("q1_date_df","wb") as fp:
   pickle.dump(q1_date_df, fp)

# %% [markdown]
# With this process, q1_date_df is up-to-date & ready for further steps.
#
# However, q1_jrnl_df needs to be analyzed & updated (if necessary) as well...

# %% [markdown]
# #### 2 - q1_jrnl_df updates:

# %% [markdown]
# The initial analysis above showed that there were 3 different problems during q1_date_fe run. These are:
#
# - for 9+1 jrnls, the CR Count is either no longer valid OR all artcls have been removed (CR_Count = 0)
#
#     _all these jrnls had >1 Req_count meaning there is reason for a re-trial & these jnrls can be marked as CR_Count = 0 & 1 accordingly_
#
#
# - for 1976 jrnls, there are no succesful DATE INFO extracted. Some of these jrnls such as 1_54942 had 37 artcls extracted & non had DATE INFO, so it can / should be dropped!
#
#     _However, further analysis below show that most of these jrnls had only <3 artcls retrieved, and therefore should be re-tried!!!_
#
# - for 11054 jrnls, the current status is PARTIAL OK, need to fix!

# %%
q1_jrnl_df.fillna(0)[q1_jrnl_df.fillna(0).Required_Count > q1_jrnl_df.fillna(0).list_total]
# Out:
#                          ISSN  Year                              Title  \
# ID
# 1_18052           (09096396,)  2013                   Wildlife Biology
# 1_24838  (10870571, 1552454X)  2010  Journal of Biomolecular Screening
# 1_24839  (10870571, 1552454X)  2012  Journal of Biomolecular Screening
# 1_24840  (10870571, 1552454X)  2014  Journal of Biomolecular Screening
# 1_24841  (10870571, 1552454X)  2011  Journal of Biomolecular Screening
# 1_24842  (10870571, 1552454X)  2015  Journal of Biomolecular Screening
# 1_24843  (10870571, 1552454X)  2016  Journal of Biomolecular Screening
# 1_24844  (10870571, 1552454X)  2013  Journal of Biomolecular Screening
# 1_66638  (24726311, 24726303)  2019                    SLAS Technology
# 1_66639  (24726311, 24726303)  2020                    SLAS Technology
#
#                                                   Sbj_Area  Total_Docs  \
# ID
# 1_18052                       {'Environmental Science': 1}          51
# 1_24838  {'Pharmacology, Toxicology and Pharmaceutics': 1}         132
# 1_24839  {'Pharmacology, Toxicology and Pharmaceutics': 1}         139
# 1_24840  {'Chemistry': 1, 'Biochemistry, Genetics and M...         139
# 1_24841  {'Pharmacology, Toxicology and Pharmaceutics': 1}         129
# 1_24842  {'Chemistry': 1, 'Biochemistry, Genetics and M...         125
# 1_24843  {'Chemistry': 1, 'Biochemistry, Genetics and M...         113
# 1_24844  {'Chemistry': 1, 'Pharmacology, Toxicology and...         118
# 1_66638                          {'Health Professions': 1}          66
# 1_66639                          {'Health Professions': 1}          73
#
#                Country            Region  \
# ID
# 1_18052        Denmark    Western Europe
# 1_24838  United States  Northern America
# 1_24839  United States  Northern America
# 1_24840  United States  Northern America
# 1_24841  United States  Northern America
# 1_24842  United States  Northern America
# 1_24843  United States  Northern America
# 1_24844  United States  Northern America
# 1_66638  United States  Northern America
# 1_66639  United States  Northern America
#
#                                     Publisher   Coverage    SJR  ...  \
# ID                                                               ...
# 1_18052  Nordic Council for Wildlife Research  1995-2020  0,822  ...
# 1_24838                SAGE Publications Inc.  1996-2017  1,017  ...
# 1_24839                SAGE Publications Inc.  1996-2017  0,964  ...
# 1_24840                SAGE Publications Inc.  1996-2017  1,155  ...
# 1_24841                SAGE Publications Inc.  1996-2017  0,987  ...
# 1_24842                SAGE Publications Inc.  1996-2017  1,080  ...
# 1_24843                SAGE Publications Inc.  1996-2017  1,347  ...
# 1_24844                SAGE Publications Inc.  1996-2017  1,000  ...
# 1_66638                SAGE Publications Inc.  2017-2020  0,632  ...
# 1_66639                SAGE Publications Inc.  2017-2020  0,714  ...
#
#          Citable Docs. (3years)  Cites / Doc. (2years)  Ref. / Doc.  CR_Count  \
# ID
# 1_18052                     130                   1,32        47,47        56
# 1_24838                     318                   2,80        26,29       150
# 1_24839                     373                   2,43        30,27       155
# 1_24840                     381                   2,41        33,05       148
# 1_24841                     341                   2,23        27,72       169
# 1_24842                     393                   2,47        39,44       111
# 1_24843                     379                   2,54        31,75        78
# 1_24844                     394                   2,11        32,87       141
# 1_66638                     125                   2,16        33,77        70
# 1_66639                     183                   2,40        35,78        70
#
#          SH_Results Current_Count Required_Count  list_total  list_succ  \
# ID
# 1_18052        True           1.0              6         0.0        0.0
# 1_24838        True           1.0              6         0.0        0.0
# 1_24839        True           0.0              8         0.0        0.0
# 1_24840        True           0.0             10         0.0        0.0
# 1_24841        True           0.0              6         0.0        0.0
# 1_24842        True           0.0             14         0.0        0.0
# 1_24843        True           0.0             10         1.0        1.0
# 1_24844        True           0.0             12         0.0        0.0
# 1_66638        True           0.0              6         0.0        0.0
# 1_66639        True           1.0             10         0.0        0.0
#
#          list_diff
# ID
# 1_18052        0.0
# 1_24838        0.0
# 1_24839        0.0
# 1_24840        0.0
# 1_24841        0.0
# 1_24842        0.0
# 1_24843        0.0
# 1_24844        0.0
# 1_66638        0.0
# 1_66639        0.0
#
# [10 rows x 24 columns]

# %%
q1_anlys[q1_anlys.list_succ == 0].sort_values("list_total", ascending=False)
# Out:
#                                                      Dates  list_total  \
# JRNL_ID
# 1_54942  [article_not_in_Scihub, article_not_in_Scihub,...          37
# 1_27702  [no_date_found, no_date_found, no_date_found, ...          22
# 1_28313  [no_date_found, no_date_found, no_date_found, ...          22
# 1_64747  [no_date_found, no_date_found, no_date_found, ...          22
# 1_45401  [article_not_in_Scihub, article_not_in_Scihub,...          20
# ...                                                    ...         ...
# 1_50636                                    [no_date_found]           1
# 1_50663                            [article_not_in_Scihub]           1
# 1_50715                                    [no_date_found]           1
# 1_35456                                    [no_date_found]           1
# 1_26742                                    [no_date_found]           1
#
#          list_succ  list_diff
# JRNL_ID
# 1_54942          0         37
# 1_27702          0         22
# 1_28313          0         22
# 1_64747          0         22
# 1_45401          0         20
# ...            ...        ...
# 1_50636          0          1
# 1_50663          0          1
# 1_50715          0          1
# 1_35456          0          1
# 1_26742          0          1
#
# [1976 rows x 4 columns]

# %%
q1_anlys[q1_anlys.list_succ == 0].list_total.value_counts().sort_index()
# Out:
# 1     955
# 2     427
# 3     230
# 4     100
# 5      68
# 6      51
# 7      36
# 8      28
# 9      15
# 10     17
# 11     15
# 12      6
# 13      6
# 14      7
# 15      3
# 16      1
# 17      2
# 18      2
# 19      1
# 20      2
# 22      3
# 37      1
# Name: list_total, dtype: int64

# %%
q1_jrnl_df[q1_jrnl_df.list_diff > 0].sort_values("list_diff",ascending=False)
# Out:
#                          ISSN  Year  \
# ID
# 1_25758  (10959203, 00368075)  2011
# 1_37840  (14764687, 00280836)  2010
# 1_25759  (10959203, 00368075)  2018
# 1_54942  (18060374, 21790302)  2019
# 1_63003  (20955138, 2053714X)  2015
# ...                       ...   ...
# 1_34098  (14653923, 00905992)  2015
# 1_34060  (14653648, 02681153)  2015
# 1_34059  (14653648, 02681153)  2013
# 1_34051  (14653419, 13557858)  2015
# 1_66912  (8756758X, 14602695)  2016
#
#                                                      Title  \
# ID
# 1_25758                                            Science
# 1_37840                                             Nature
# 1_25759                                            Science
# 1_54942              Periodico Tche Quimica (discontinued)
# 1_63003                            National Science Review
# ...                                                    ...
# 1_34098                               Nationalities Papers
# 1_34060                          Health Education Research
# 1_34059                          Health Education Research
# 1_34051                               Ethnicity and Health
# 1_66912  Fatigue and Fracture of Engineering Materials ...
#
#                                                   Sbj_Area  Total_Docs  \
# ID
# 1_25758  {'Arts and Humanities': 1, 'Multidisciplinary'...        2093
# 1_37840                           {'Multidisciplinary': 1}        2464
# 1_25759  {'Arts and Humanities': 1, 'Multidisciplinary'...        2943
# 1_54942  {'Multidisciplinary': 1, 'Health Professions': 1}         265
# 1_63003                           {'Multidisciplinary': 1}          75
# ...                                                    ...         ...
# 1_34098   {'Social Sciences': 2, 'Arts and Humanities': 1}          47
# 1_34060                             {'Social Sciences': 1}          50
# 1_34059              {'Social Sciences': 1, 'Medicine': 1}          93
# 1_34051   {'Arts and Humanities': 1, 'Social Sciences': 1}          36
# 1_66912         {'Materials Science': 1, 'Engineering': 2}         120
#
#                 Country            Region  \
# ID
# 1_25758   United States  Northern America
# 1_37840  United Kingdom    Western Europe
# 1_25759   United States  Northern America
# 1_54942          Brazil     Latin America
# 1_63003  United Kingdom    Western Europe
# ...                 ...               ...
# 1_34098  United Kingdom    Western Europe
# 1_34060  United Kingdom    Western Europe
# 1_34059  United Kingdom    Western Europe
# 1_34051  United Kingdom    Western Europe
# 1_66912  United Kingdom    Western Europe
#
#                                                  Publisher  \
# ID
# 1_25758  American Association for the Advancement of Sc...
# 1_37840                            Nature Publishing Group
# 1_25759  American Association for the Advancement of Sc...
# 1_54942                                 Tche Quimica Group
# 1_63003                            Oxford University Press
# ...                                                    ...
# 1_34098                                          Routledge
# 1_34060                            Oxford University Press
# 1_34059                            Oxford University Press
# 1_34051                                          Routledge
# 1_66912                     Wiley-Blackwell Publishing Ltd
#
#                      Coverage     SJR  ...  Citable Docs. (3years)  \
# ID                                     ...
# 1_25758  1880-1881, 1883-2020  14,238  ...                    4336
# 1_37840             1869-2020  16,465  ...                    4587
# 1_25759  1880-1881, 1883-2020  13,251  ...                    4537
# 1_54942             2011-2020   0,689  ...                     229
# 1_63003             2014-2020   1,273  ...                      55
# ...                       ...     ...  ...                     ...
# 1_34098  1972-1985, 1987-2020   0,676  ...                     153
# 1_34060             1986-2020   0,835  ...                     301
# 1_34059             1986-2020   1,226  ...                     273
# 1_34051             1996-2020   0,797  ...                     114
# 1_66912             1979-2020   1,286  ...                     353
#
#          Cites / Doc. (2years)  Ref. / Doc.  CR_Count  SH_Results  \
# ID
# 1_25758                  13,62        16,15      4060        True
# 1_37840                  14,31        14,62      4180        True
# 1_25759                  15,40        12,88      4882        True
# 1_54942                   2,43        33,12       267        True
# 1_63003                   2,57        40,71        85        True
# ...                        ...          ...       ...         ...
# 1_34098                   1,07        67,23        98        True
# 1_34060                   1,57        40,98        97        True
# 1_34059                   2,38        35,59       105        True
# 1_34051                   2,13        43,17        32        True
# 1_66912                   2,63        36,78       175        True
#
#         Current_Count Required_Count  list_total  list_succ  list_diff
# ID
# 1_25758           1.0             97        97.0       17.0       80.0
# 1_37840           1.0             85        85.0       12.0       73.0
# 1_25759           1.0             42        42.0        5.0       37.0
# 1_54942           1.0             37        37.0        0.0       37.0
# 1_63003           1.0             45        45.0        9.0       36.0
# ...               ...            ...         ...        ...        ...
# 1_34098           1.0              4         4.0        3.0        1.0
# 1_34060           1.0              1         1.0        0.0        1.0
# 1_34059           1.0              2         2.0        1.0        1.0
# 1_34051           1.0              5         5.0        4.0        1.0
# 1_66912           1.0              2         2.0        1.0        1.0
#
# [11054 rows x 24 columns]

# %% [markdown]
# NOTE: IT IS IMPORTANT TO NOTE THAT, DURING PARTIAL FIX OR OTHER RUNS, IT IS REEEEAAAAALLLYYY CRUCIAL TO CONSIDER "FAILED" DOIs!!!!!
#
# To ensure unnnecessary duplicate record retrival for already failed artcls!

# %%
set(q1_meta_fe.DOI.tolist()).difference(set(q1_date_df.index))
# Out:
# 29774

# %%
q1_jrnl_df.fillna(0)[q1_jrnl_df.fillna(0).Required_Count < q1_jrnl_df.fillna(0).list_total]
# Out:
#                          ISSN  Year                        Title  \
# ID
# 1_49971  (16512316, 16506073)  2014  Cognitive Behaviour Therapy
#
#                   Sbj_Area  Total_Docs Country          Region  \
# ID
# 1_49971  {'Psychology': 1}          31  Sweden  Western Europe
#
#                      Publisher   Coverage    SJR  ...  Citable Docs. (3years)  \
# ID                                                ...
# 1_49971  Taylor and Francis AS  2002-2020  1,391  ...                      87
#
#          Cites / Doc. (2years)  Ref. / Doc.  CR_Count  SH_Results  \
# ID
# 1_49971                   2,39        45,77        38        True
#
#         Current_Count Required_Count  list_total  list_succ  list_diff
# ID
# 1_49971           1.0              5        10.0        9.0        1.0
#
# [1 rows x 24 columns]

# %%
len(q1_meta_fe)
# Out:
# 138184

# %%
len(q1_date_fe)
# Out:
# 108345

# %%
138184-108345
# Out:
# 29839

# %%
29839-29774
# Out:
# 65
